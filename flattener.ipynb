# %% [markdown]
# #### This notebook was used to find lists and dictionaries within the "features" dictionary where Gemini extracted features. They needed to be flattened because I didn't want to make and parse lists and dictionaries in databases.

# %%
import os
import json


def flatten_json(json_obj, parent_key='', sep='_'):
    items = {}
    for k, v in json_obj.items():
        new_key = f"{parent_key}{sep}{k}" if parent_key else k
        if isinstance(v, dict):
            if parent_key == "features":
                items.update(flatten_json(v, parent_key=new_key, sep=sep))
            else:
                items[new_key] = v
        elif isinstance(v, list):
            for i, item in enumerate(v):
                if isinstance(item, dict):
                    items.update(flatten_json(item, parent_key=new_key, sep=sep))
                else:
                    items[new_key] = v
        else:
            items[new_key] = v
    return items

def process_files_in_folder(input_folder, output_folder):
    for filename in os.listdir(input_folder):
        if filename.endswith('.json'):
            input_file_path = os.path.join(input_folder, filename)
            with open(input_file_path, 'r', encoding='utf-8') as file:
                json_data = json.load(file)
                flattened_data = flatten_json(json_data)
                output_file_path = os.path.join(output_folder, f"{filename}")
                with open(output_file_path, 'w', encoding='utf-8') as output_file:
                    json.dump(flattened_data, output_file, ensure_ascii=False, indent=4)

                    
# Replace 'input_folder_path' and 'output_folder_path' with your input and output directory paths
input_folder_path = r'C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_with_lists_dicts'
output_folder_path = r'C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_dict_flattened'

process_files_in_folder(input_folder_path, output_folder_path)

# %%
import os
import json

def has_lists_or_dicts(data):
    if isinstance(data, dict):
        for value in data.values():
            if isinstance(value, (list, dict)):
                return True
    elif isinstance(data, list):
        for item in data:
            if isinstance(item, (list, dict)):
                return True
    return False

def check_features_for_lists_dicts(folder_path):
    count= 0
    for filename in os.listdir(folder_path):
        if filename.endswith('.json'):
            file_path = os.path.join(folder_path, filename)
            with open(file_path, 'r', encoding='utf-8') as file:
                try:
                    json_data = json.load(file)
                    if 'features' in json_data and has_lists_or_dicts(json_data['features']):
                        print(f"{file_path}: 'features' dictionary contains lists or dictionaries.")
                        count+=1
                except Exception as e:
                    print(f"Error while processing {file_path}: {e}")
    print(count)

# Replace 'folder_path' with the path to your directory containing JSON files
folder_path = r'C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template'

check_features_for_lists_dicts(folder_path)
# Out:
# 0

# %%
import os
import json
import shutil

def has_lists_or_dicts(data):
    if isinstance(data, dict):
        for value in data.values():
            if isinstance(value, (list, dict)):
                return True
    elif isinstance(data, list):
        for item in data:
            if isinstance(item, (list, dict)):
                return True
    return False

def check_and_copy_features_for_lists_dicts(source_folder, destination_folder):
    count = 0
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)
    
    for filename in os.listdir(source_folder):
        if filename.endswith('.json'):
            file_path = os.path.join(source_folder, filename)
            with open(file_path, 'r', encoding='utf-8') as file:
                try:
                    json_data = json.load(file)
                    if 'features' not in json_data or json_data['features'] == None or json_data['features'] == {}:
                        print(f"{file_path}: 'features' dictionary contains lists or dictionaries.")
                        shutil.copy(file_path, destination_folder)
                        count += 1
                except Exception as e:
                    print(f"Error while processing {file_path}: {e}")
    
    print(f"Total files copied: {count}")

# Replace 'source_folder' with the path to your directory containing JSON files
source_folder = r'C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template'
# Replace 'destination_folder' with the path to your target directory where you want to copy the files
destination_folder = r'C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_missing_features'

check_and_copy_features_for_lists_dicts(source_folder, destination_folder)
# Out:
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_BANZ-0-3-god--Kaleidoscope.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_BARNER-Astoria-Light-Jade.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_BARNER-Chamberi---Dark-Green.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_BARNER-Dalston---Coconut-Milk.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_BARNER-Le-Marais---Light-Tortoise.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_BOJLER-TING-INOX-BVE80-L-SKP---DES---.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_CANYON-CCL11-Wipes-for-Screen.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_CANYON-CNE-CMP2.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_DALECINSKO-ZA-TV-HAMA-for-LG-TVs.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_Dualshock-Controller-SONY-PS4-Magma-Red-V2.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_Everest-EKW-28-Wireless-White-Grey-Round-Key.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_Evil-West-.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_GENIUS-KM-160-Black.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_HAMA-Adapter-Cat5-45047.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_HP-302-Tri-Color.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_HP-DeskJet-2320-All-in-One.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_HP-OMEN-100.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_HP-Wired-150-BLK.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_HP-Wireless-330-BLK.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_HYTECH-HY-XH12-Magnet.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_IGRA-ZA-PS4-God-of-War.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_IGRA-ZA-PS4-The-Last-of-Us.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_IGRA-ZA-PS5-DEAD-SPACE.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_IGRA-ZA-PS5-SONIC-SUPERSTARS.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_KOMPATIBILEN-TONER-ZA-HP-LJ-Pro-M-Serie-203-DN-203-DW-203-203-DN-203-DW.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_LOGITECH-DESKTOP-MK-120.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_MELICONI-Ceiling-mount.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_MELICONI-Floor-stand.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_MELICONI-Wall-Mounted-for-pedal.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_MELICONI-Wall-Mounted-For-Space-Saving.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_MIKADO-MD-158-1-1-USB.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_MOYE-Venture-4K.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_NETWORK-CABLE-S-BOX-UTP-CAT-5E-1m.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_NINTENDO-SWITCH-13-SENTINELS---SW.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_NINTENDO-SWITCH-CONSTRUCTOR-PLUS.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_NINTENDO-SWITCH-MONSTER-HUNTER-RISE.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_NINTENDO-SWITCH-WORLD-OF-FINAL-FANTASY-MAXIMA--CIAB-.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_PANASONIC-BK-4MCDE-4BE.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_PANASONIC-CR-2016-1-1.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_PHILIPS-GC-026--00.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_PHILIPS-LR-6P6-BP-10-AA.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_PHILIPS-QP-420-50-2-pcs.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_PHILIPS-SCF080-02.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_PHILIPS-SCF080-03.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_PHILIPS-SH-50-50-.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_PHILIPS-SH71-50-SH-HEAD-5000-7000.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_PHILIPS-TT-2000--43.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_PROJECTOR-ACER-X1326AWH-4000-AL-HDMI.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_PS-Horizon-Forbidden-West-Collectors-Edition.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_PS4-Back-4-Blood.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_PS4-GRAN-TURISMO-7.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_PS4-Kingdom-Hearts-3-S.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_PS4-PERSONA-5-STRIKERS-LIMITED-EDITION.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_PS4-Ratchet---Clank-Trilogy-HITS.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_PS4-SONIC-SUPERSTARS.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_PS4-Spiderman-Miles-Morales.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_PS4-STRANGER-OF-PARADISE-FINAL-FANTASY-ORIGIN.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_PS4-The-Last-of-Us-Part-II.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_PS4-TINY-TINAS-WONDERLANDS.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_PS5-Deathloop.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_PS5-Dualsense-Wireless-Controller---Grey-Camo.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_PS5-Dualsense-Wireless-Controller-Cobalt-Blue.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_PS5-Dualsense-Wireless-Controller-Cosmic-Red.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_PS5-Dualsense-Wireless-Controller-Purple.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_PS5-Dualsense-Wireless-Controller-Volcanic-Red.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_PS5-Dualsense-Wireless-Controller.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_PS5-GHOSTWIRE-TOKYO.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_PS5-GRAN-TURISMO-7.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_PS5-Marvel's-Guardians-of-the-Galaxy.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_PS5-Marvels-Spider-Man-2.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_PS5-STRANGER-OF-PARADISE-FINAL-FANTASY-ORIGIN.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_PS5-Tekken-8.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_RAZER-Sphex-V3-Ultra-Thin-Gaming-Mat---Small.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_REDRAGON-Suzaku-Gaming-Extended.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_ROWENTA-VU-6210-F0.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_S-LINK-SL-AT30-Black-PRM-Magnetic.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_S-LINK-SL-AT43-Magnet---Suction-Cup.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_SAMSUNG-32--VG-SCFT32BE-XC-Beige.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_SAMSUNG-32--VG-SCFT32VL-XC.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_SAMSUNG-55--VG-SCFA55BWBXC-Brown.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_SAMSUNG-55--VG-SCFT55BE-Beige.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_SAMSUNG-65--VG-SCFT65BE-Beige.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_SAMSUNG-75--VG-SCFA75BWBXC-Brown.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_SAMSUNG-75--VG-SCFA75TKBXC-Beige.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_SAMSUNG-75--VG-SCFA75WTBXC-White-.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_SAMSUNG-75--VG-SCFT75BW-Brown.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_SAMSUNG-WMN-M25EA-XC.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_SNOPY-SN-140M-Black--34537-.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_SNOPY-SN-340M-Black--22072-.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_Spider-Man-Miles-Morales.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_Switch-Wheel-for-Joy-Con-Dualpack.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_TING-INOX-BVE-60L-SKP--DES-.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_VARTA-ELECTRONICS-CR2016-3V--1.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_VARTA-HIGH-ENERGY-9V--1.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_Windows-11-Pro-Eng-64-bit-DSP-DVD.json: 'features' dictionary contains lists or dictionaries.
# C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template\processed_WPRO-BABY-DRZAC-ZA-ZAGREVANJE-VO-MIKRO-PECKA.json: 'features' dictionary contains lists or dictionaries.
# Total files copied: 96

# %%
import os
import json

def has_lists_or_dicts(data):
    if isinstance(data, dict):
        for value in data.values():
            if isinstance(value, (list, dict)):
                return True
    elif isinstance(data, list):
        for item in data:
            if isinstance(item, (list, dict)):
                return True
    return False

def check_features_for_lists_dicts(folder_path):
    count= 0
    for filename in os.listdir(folder_path):
        if filename.endswith('.json'):
            file_path = os.path.join(folder_path, filename)
            with open(file_path, 'r', encoding='utf-8') as file:
                try:
                    json_data = json.load(file)
                    if 'features' not in json_data or json_data['features'] == None or json_data['features'] == {}:
                        print(f"{file_path}: 'features' dictionary contains lists or dictionaries.")
                        count+=1
                except Exception as e:
                    print(f"Error while processing {file_path}: {e}")
    print(count)

# Replace 'folder_path' with the path to your directory containing JSON files
folder_path = r'C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_categories_fixed\all_extracted_universal_template'

check_features_for_lists_dicts(folder_path)
# Out:
# 0
