# %% [markdown]
# #### This was used to test extraction of features using the Anthropic Claude 3 Sonnet model through an API.

# %%
from langchain_anthropic import ChatAnthropic
from langchain_core.prompts import ChatPromptTemplate
from dotenv import load_dotenv
import os
from langchain_core.prompts import PromptTemplate
from langchain.chains import LLMChain
import json

# %%
load_dotenv()
ANTHROPIC_API_KEY = os.getenv("ANTHROPIC_API_KEY")

# %%
llm = ChatAnthropic(temperature=0, model_name="claude-3-sonnet-20240229")

# %%
# Define the prompt template
prompt_template = """
Extract the features of the provided product and represent them as separate key-value pairs in a JSON format. Ensure that each feature is listed individually without any lists or dictionaries within the features. If the feature includes a specific attribute (e.g., size, capacity, type, port), include that as well. List each port as a separate feature. Return the extracted features as a JSON object.
Input:
{
  "url": "https://www.neptun.mk/categories/gaming_laptopi/LENOVO-IdeaPad-Gaming-3-15ACH6-R5-5500H-16GB-512GB-RTX-2050-4GB",
  "title": "",
  "warranty": "24",
  "regular_price": "39.999",
  "happy_price": "36.999",
  "description": [
    "Лаптоп",
    "Дисплеј:15.6\" (39.6cm)",
    "Резолуција:(1920x1080) FHD, IPS 250nits Anti-glare, 45% NTSC, 60Hz",
    "Chipset: AMD SoC Platform",
    "Процесор:AMD Ryzen™ 5 5500H (4C / 8T, 3.3 / 4.2GHz, 2MB L2 / 8MB L3)",
    "Графичка:NVIDIA® GeForce RTX™ 2050 4GB GDDR6",
    "RAM меморија:16GB DDR4-3200",
    "Диск (Storage):512GB SSD M.2 2242 PCIe® 4.0x4 NVMe®",
    "Без оперативен систем",
    "WLAN + Bluetooth: 11ac 2x2 + BT5.0",
    "Камера:HD 720p with Privacy Shutter",
    "Аудио: High Definition (HD) Audio, Realtek® ALC3287 codec",
    "Звучници: Stereo speakers, 2W x2, Nahimic Audio",
    "Микрофон:2x, Array",
    "Тастатура: White Backlit, English",
    "Wireless:Wi-Fi® 6, 11ax 2x2 + BT5.1",
    "Порти:",
    "2x USB 3.2 Gen 1",
    "1x USB-C® 3.2 Gen 1 (support data transfer only)",
    "1x HDMI® 2.0",
    "1x Headphone / microphone combo jack (3.5mm)",
    "1x Ethernet (RJ-45)",
    "1x Power connector",
    "Батерија: Integrated 45Wh",
    "Power Adapter: 135W Slim Tip (3-pin)"
  ],
  "category": "gaming_laptopi"
}
Output:
{
  "url": "https://www.neptun.mk/categories/gaming_laptopi/LENOVO-IdeaPad-Gaming-3-15ACH6-R5-5500H-16GB-512GB-RTX-2050-4GB",
  "title": "",
  "regular_price": "39.999",
  "happy_price": "36.999",
  "warranty": "24",
  "features": {
    "Display": "15.6\" (39.6cm)",
    "Resolution": "1920x1080 FHD, IPS 250nits Anti-glare",
    "Chipset": "AMD SoC Platform",
    "Processor": "AMD Ryzen™ 5 5500H (4C / 8T, 3.3 / 4.2GHz, 2MB L2 / 8MB L3)",
    "Graphics": "NVIDIA® GeForce RTX™ 2050 4GB GDDR6",
    "RAM": "16GB DDR4-3200",
    "Storage": "512GB SSD M.2 2242 PCIe® 4.0x4 NVMe®",
    "Operating System": "Без оперативен систем",
    "Wireless": "Wi-Fi® 6, 11ax 2x2 + BT5.1",
    "Camera": "HD 720p with Privacy Shutter",
    "Audio": "High Definition (HD) Audio, Realtek® ALC3287 codec",
    "Speakers": "Stereo speakers, 2W x2, Nahimic Audio",
    "Microphone": "2x, Array",
    "Keyboard": "White Backlit, English",
    "Headset Port": "1 x Headset (headphone and microphone combo) port",
    "RJ45 Ethernet Port": "1 x RJ45 Ethernet port",
    "USB Ports": "3 x USB 3.2 Gen 1 ports",
    "HDMI Port": "1 x HDMI 2.0 port",
    "USB-C Port": "1 x USB-C 3.2 Gen 1 port (support data transfer only)",
    "Battery": "Integrated 45Wh",
    "Power Adapter": "135W Slim Tip (3-pin)",
    "Display Port": false
  }
}
Input:
{
  "url": "https://www.neptun.mk/categories/gaming_laptopi/ACER-AN515-57-53A7-i5-11400H-8GB-512B-RTX-3050-4GB",
  "title": "ЛАПТОП ACER AN515-57-53A7 I5-11400H/8GB/512B/RTX 3050 4GB",
  "warranty": "24",
  "regular_price": "55.999",
  "happy_price": "47.999",
  "description": [
    "Лаптоп",
    "Дисплеј:15.6\" (39.6cm)",
    "Резолуција:(1920 x 1080) FHD IPS 144Hz",
    "Процесор:Intel® Core i5-11400H 2.70 GHz Hexa-core",
    "Графика:NVIDIA® GeForce RTX 3050 4GB",
    "RAM меморија:8GB DDR4",
    "Диск (Storage):512GB SSD",
    "LAN:IEEE 802.11 a/b/g/n/ac/ax",
    "Gigabit Ethernet",
    "Bluetooth 5.2",
    "Микрофон",
    "Оперативен систем:UEFI Shell",
    "Порти:",
    "HDMI, USB, LAN, Type C",
    "Батерија:4-cell (Li-Ion) - 8h"
  ],
  "category": "gaming_laptopi"
}
Output:
{
  "url": "https://www.neptun.mk/categories/gaming_laptopi/ACER-AN515-57-53A7-i5-11400H-8GB-512B-RTX-3050-4GB",
  "title": "ЛАПТОП ACER AN515-57-53A7 I5-11400H/8GB/512B/RTX 3050 4GB",
  "regular_price": "55.999",
  "happy_price": "47.999",
  "warranty": "24",
  "features": {
    "Display": "15.6\" (39.6cm)",
    "Resolution": "1920 x 1080 FHD IPS 144Hz",
    "Processor": "Intel® Core i5-11400H 2.70 GHz Hexa-core",
    "Graphics": "NVIDIA® GeForce RTX 3050 4GB",
    "RAM": "8GB DDR4",
    "Storage": "512GB SSD",
    "LAN": "IEEE 802.11 a/b/g/n/ac/ax, Gigabit Ethernet",
    "Bluetooth": "5.2",
    "Microphone": true,
    "Operating System": "UEFI Shell",
    "HDMI Port": "1 x HDMI port",
    "USB Port": "1 x USB port",
    "LAN Port": "1 x LAN port",
    "Type C Port": "1 x Type C port",
    "Battery": "4-cell (Li-Ion) - 8h"
  }
}

Input:
{
"url": "https://www.neptun.mk/categories/gaming_laptopi/DELL-G15-5530-i5-13450HX-16GB-DDR5-512GB-RTX-3050-6GB",
"title": "ЛАПТОП DELL G15 5530 I5-13450HX/16GB DDR5/512GB/RTX 3050 6GB",
"warranty": "36",
"regular_price": "69.999",
"happy_price": "62.999",
"description": [
"Лаптоп",
"Дисплеј:15.6" (39.6cm)",
"Резолуција: (1920 x 1080) FHD 120Hz 250 nits WVA Anti- Glare LED Backlit Narrow Border Display",
"Процесор:13th Gen Intel® Core™ i5-13450HX (20 MB cache, 10 cores, 16 threads, up to 4.60 GHz Turbo)",
"Графика:NVIDIA® GeForce RTX™ 3050, 6 GB GDDR6",
"RAM Меморија: 16 GB: 2 x 8 GB, DDR5, 4800 MT/s",
"Диск (Storage): 512 GB, M.2, PCIe NVMe, SSD",
"Wi-Fi 6 AX201, 2x2, 802.11ax, Bluetooth® 5.2",
"Камера:Integrated widescreen HD (720p) Webcam with Single Array Digital Microphone",
"Порти:",
"1 x Headset (headphone and microphone combo) port",
"1 x RJ45 Ethernet port",
"3 x USB 3.2 Gen 1 ports",
"1 x HDMI 2.1 port",
"1 x USB-C 3.2 Gen 2 port with DisplayPort™",
"Батерија: 3 Cell, 56 Wh, integrated",
"Полнач: 240W AC Adapter",
"Позадинско осветлување на тастатурата (backlit keyboard)",
"Carbon BlackDark Shadow Gray with Black thermal shelf"
],
"category": "gaming_laptopi"
}
Output:
{
  "url": "https://www.neptun.mk/categories/gaming_laptopi/DELL-G15-5530-i5-13450HX-16GB-DDR5-512GB-RTX-3050-6GB",
  "title": "ЛАПТОП DELL G15 5530 I5-13450HX/16GB DDR5/512GB/RTX 3050 6GB",
  "warranty": "36",
  "regular_price": "69.999",
  "happy_price": "62.999",
  "features": {
    "Display": "15.6\" (39.6cm)",
    "Resolution": "(1920 x 1080) FHD 120Hz 250 nits WVA Anti-Glare LED Backlit Narrow Border Display",
    "Processor": "13th Gen Intel® Core™ i5-13450HX (20 MB cache, 10 cores, 16 threads, up to 4.60 GHz Turbo)",
    "Graphics": "NVIDIA® GeForce RTX™ 3050, 6 GB GDDR6",
    "RAM": "16 GB: 2 x 8 GB, DDR5, 4800 MT/s",
    "Storage": "512 GB, M.2, PCIe NVMe, SSD",
    "Wireless": "Wi-Fi 6 AX201, 2x2, 802.11ax, Bluetooth® 5.2",
    "Camera": "Integrated widescreen HD (720p) Webcam with Single Array Digital Microphone",
    "Headset Port": "1 x Headset (headphone and microphone combo) port",
    "RJ45 Ethernet Port": "1 x RJ45 Ethernet port",
    "USB Ports": "3 x USB 3.2 Gen 1 ports",
    "HDMI Port": "1 x HDMI 2.1 port",
    "USB-C Port": "1 x USB-C 3.2 Gen 2 port™",
    "Display Port": true,
    "Battery": "3 Cell, 56 Wh, integrated",
    "Power Adapter": "240W AC Adapter",
    "Backlit Keyboard": "Pozadinsko осветлување на тастатурата (backlit keyboard)",
    "Color": "Carbon BlackDark Shadow Gray with Black thermal shelf"
  }
}
Provided product:
{{text}}
"""
prompt = PromptTemplate(template=prompt_template, input_variables=["text"], template_format="jinja2")
chain = LLMChain(llm=llm, prompt=prompt)

# %%
# Directory containing JSON files
input_directory = r"C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_with_categories\gaming_laptopi"
# Directory to save processed JSON files
output_directory = r"C:\Users\tomce\OneDrive - UKIM, FINKI\Desktop\Fakultet 3ta Godina\2 Sesti Semestar\0 DATA SCIENCE SEMINARSKA\1 Starting Over\products_opus_testing"

# Create the output directory if it doesn't exist
os.makedirs(output_directory, exist_ok=True)

# %%
# Counter to limit processing to 10 files
counter = 0
max_files = 10

# Loop through all files in the input directory
for filename in os.listdir(input_directory):
    if filename.endswith('.json'):
        input_filepath = os.path.join(input_directory, filename)
        
        # Open and read each JSON file
        with open(input_filepath, 'r') as file:
            data = json.load(file)
            text = json.dumps(data)
        
            print(text)
            
            # Process the JSON data using the LangChain model
            structured_data = chain.invoke({"text": text})
            
            # Determine the output file path
            output_filename = f"processed_{filename}"
            output_filepath = os.path.join(output_directory, output_filename)
            
            # Write the processed data to the output file
            with open(output_filepath, 'w') as outfile:
                json.dump(structured_data, outfile, indent=4)
        
        # Increment the counter
        counter += 1

print(f"Processed {counter} JSON files and saved them in {output_directory}")
# Out:
# {"url": "https://www.neptun.mk/categories/gaming_laptopi/ACER-AN515-57-53A7-i5-11400H-8GB-512B-RTX-3050-4GB", "title": "\u041b\u0410\u041f\u0422\u041e\u041f ACER AN515-57-53A7 I5-11400H/8GB/512B/RTX 3050 4GB", "warranty": "24", "regular_price": "55.999", "happy_price": "47.999", "description": ["\u041b\u0430\u043f\u0442\u043e\u043f\n\u0414\u0438\u0441\u043f\u043b\u0435\u0458:15.6\" (39.6cm)\n\u0420\u0435\u0437\u043e\u043b\u0443\u0446\u0438\u0458\u0430:(1920 x 1080) FHD IPS 144Hz\n\u041f\u0440\u043e\u0446\u0435\u0441\u043e\u0440:Intel\u00ae Core i5-11400H 2.70 GHz Hexa-core\n\u0413\u0440\u0430\u0444\u0438\u043a\u0430:NVIDIA\u00ae GeForce RTX 3050 4GB\nRAM \u043c\u0435\u043c\u043e\u0440\u0438\u0458\u0430:8GB DDR4\n\u0414\u0438\u0441\u043a (Storage):512GB SSD\nLAN:IEEE 802.11 a/b/g/n/ac/ax\nGigabit Ethernet\nBluetooth 5.2\n\u041c\u0438\u043a\u0440\u043e\u0444\u043e\u043d\n\u041e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0435\u043d \u0441\u0438\u0441\u0442\u0435\u043c:UEFI Shell\n\u041f\u043e\u0440\u0442\u0438:\nHDMI, USB, LAN, Type C\n\u0411\u0430\u0442\u0435\u0440\u0438\u0458\u0430:4-cell (Li-Ion) - 8h"], "category": "gaming_laptopi"}
# {"url": "https://www.neptun.mk/categories/gaming_laptopi/ACER-Aspire-5-A515-57G-50CS-i5-1240P-16GB-512GB-RTX-2050-4GB", "title": "\u041b\u0410\u041f\u0422\u041e\u041f ACER ASPIRE 5 A515-57G-50CS I5-1240P/16GB/512GB/RTX 2050 4GB", "warranty": "24", "regular_price": "53.999", "happy_price": "47.999", "description": ["\u041b\u0430\u043f\u0442\u043e\u043f\n\u0414\u0438\u0441\u043f\u043b\u0435\u0458:15.6\" (39.6cm)\n\u0420\u0435\u0437\u043e\u043b\u0443\u0446\u0438\u0458\u0430:(1920 x 1080) FHD, IPS, SlimBezel\n\u041f\u0440\u043e\u0446\u0435\u0441\u043e\u0440:Intel\u00ae Core\u2122 i5-1240P (12C, 16T, Max Turbo Frequency 4.40 GHz, Cache 12 MB)\n\u0413\u0440\u0430\u0444\u0438\u043a\u0430:NVIDIA\u00ae GeForce RTX\u2122 2050 4GB GDDR6\nRAM \u043c\u0435\u043c\u043e\u0440\u0438\u0458\u0430:16GB DDR4\n\u0414\u0438\u0441\u043a (Storage):512GB PCIe NVMe SSD\nLAN:IEEE 802.11 a/b/g/n/ac/ax\nGigabit Ethernet\nWireless: Wi-Fi 6 AX + BT\nAcer PBA fingerprint reader\nHD TNR Camera\n\u0411\u0435\u0437 \u043e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0435\u043d \u0441\u0438\u0441\u0442\u0435\u043c\n\u0411\u0430\u0442\u0435\u0440\u0438\u0458\u0430:50Wh Li-ion\n\u0410\u0434\u0430\u043f\u0442\u0435\u0440: 90W"], "category": "gaming_laptopi"}
# {"url": "https://www.neptun.mk/categories/gaming_laptopi/ACER-Aspire-5-A515-57G-7503-i7-1260P-16GB-512GB-RTX-2050-4GB", "title": "\u041b\u0410\u041f\u0422\u041e\u041f ACER ASPIRE 5 A515-57G-7503 I7-1260P/16GB/512GB/RTX 2050 4GB", "warranty": "24", "regular_price": "62.999", "happy_price": "53.999", "description": ["\u041b\u0430\u043f\u0442\u043e\u043f\n\u0414\u0438\u0441\u043f\u043b\u0435\u0458:15.6\" (39.6cm)\n\u0420\u0435\u0437\u043e\u043b\u0443\u0446\u0438\u0458\u0430:(1920 x 1080) FHD, IPS, SlimBezel\n\u041f\u0440\u043e\u0446\u0435\u0441\u043e\u0440:Intel\u00ae Core\u2122 i7-1260P(12C, 16T, Max Turbo Frequency 4.70 GHz, Cache 18 MB)\n\u0413\u0440\u0430\u0444\u0438\u043a\u0430:NVIDIA\u00ae GeForce RTX\u2122 2050 4GB GDDR6\nRAM \u043c\u0435\u043c\u043e\u0440\u0438\u0458\u0430:16 GB DDR4 3200MHz\n\u0414\u0438\u0441\u043a (Storage):512GB PCIe NVMe SSD\nAcer PBA fingerprint reader\nGigabit Ethernet\nWireless: IEEE 802.11ax + BT\nHD TNR Camera\n\u0411\u0435\u0437 \u043e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0435\u043d \u0441\u0438\u0441\u0442\u0435\u043c\n\u0411\u0430\u0442\u0435\u0440\u0438\u0458\u0430:50Wh Li-ion\n\u0410\u0434\u0430\u043f\u0442\u0435\u0440: 90W"], "category": "gaming_laptopi"}
# {"url": "https://www.neptun.mk/categories/gaming_laptopi/ACER-Aspire-7-A715-76G-50NJ-i5-12450H-8GB-512GB-RTX-2050-4GB", "title": "", "warranty": "24", "regular_price": "44.999", "happy_price": "39.999", "description": ["\u041b\u0430\u043f\u0442\u043e\u043f\n\u0414\u0438\u0441\u043f\u043b\u0435\u0458:15.6\" (39.6cm)\n\u0420\u0435\u0437\u043e\u043b\u0443\u0446\u0438\u0458\u0430:(1920 x 1080) FHD, IPS, 144 Hz\n\u041f\u0440\u043e\u0446\u0435\u0441\u043e\u0440:Intel\u00ae Core\u2122 i5-12450H processor Octa-core 3.30GHz, 12MB cache\n\u0413\u0440\u0430\u0444\u0438\u043a\u0430:NVIDIA\u00ae GeForce RTX\u2122 2050 4GB GDDR6\nRAM \u043c\u0435\u043c\u043e\u0440\u0438\u0458\u0430:8GB DDR4\n\u0412\u0433\u0440\u0430\u0434\u0435\u043d\u0438 \u0437\u0432\u0443\u0447\u043d\u0438\u0446\u0438 \u04452\n\u0414\u0438\u0441\u043a (Storage):512GB PCIe NVMe SSD\nLAN:IEEE 802.11ax\nBluetooth: 5.1\nFingerprint reader\n\u0412\u0433\u0440\u0430\u0434\u0435\u043d \u043c\u0438\u043a\u0440\u043e\u0444\u043e\u043d\n\u041f\u0440\u0438\u043a\u043b\u0443\u0447\u043e\u0446\u0438:\nx1 HDMI\nx3 USB 3.2 Gen 1 Type-A\nx1 USB 3.2 Gen 2 Type-C\nx1 Network (RJ-45)\nKeyboard Backlight\n\u0411\u0435\u0437 \u043e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0435\u043d \u0441\u0438\u0441\u0442\u0435\u043c\n\u0411\u0430\u0442\u0435\u0440\u0438\u0458\u0430:5.5h, 3-cell , Lithium Ion (Li-Ion)\n\u0410\u0434\u0430\u043f\u0442\u0435\u0440: 135W"], "category": "gaming_laptopi"}
# {"url": "https://www.neptun.mk/categories/gaming_laptopi/ACER-Aspire-7-A715-76G-77DS-i7-12650H-16GB-512GB-RTX-2050-4GB", "title": "\u041b\u0410\u041f\u0422\u041e\u041f ACER ASPIRE 7 A715-76G-77DS I7-12650H/16GB/512GB/RTX 2050 4GB", "warranty": "24", "regular_price": "52.999", "happy_price": "46.999", "description": ["\u041b\u0430\u043f\u0442\u043e\u043f\n\u0414\u0438\u0441\u043f\u043b\u0435\u0458:15.6\" (39.6cm)\n\u0420\u0435\u0437\u043e\u043b\u0443\u0446\u0438\u0458\u0430:(1920 x 1080) FHD, IPS, 144 Hz\n\u041f\u0440\u043e\u0446\u0435\u0441\u043e\u0440:Intel\u00ae Core\u2122 i7-12650H 10C, 16T, 4.70GHz, 24MB cache\n\u0413\u0440\u0430\u0444\u0438\u043a\u0430:NVIDIA\u00ae GeForce RTX\u2122 2050 4GB GDDR6\nRAM \u043c\u0435\u043c\u043e\u0440\u0438\u0458\u0430:16GB DDR4\n\u0414\u0438\u0441\u043a (Storage):512GB PCIe NVMe SSD\n\u0412\u0433\u0440\u0430\u0434\u0435\u043d\u0438 \u0437\u0432\u0443\u0447\u043d\u0438\u0446\u0438 \u04452\nLAN:IEEE 802.11ax\nBluetooth: 5.1\nFingerprint reader\n\u0412\u0433\u0440\u0430\u0434\u0435\u043d \u043c\u0438\u043a\u0440\u043e\u0444\u043e\u043d\n\u041f\u0440\u0438\u043a\u043b\u0443\u0447\u043e\u0446\u0438:\nx1 HDMI\nx3 USB 3.2 Gen 1 Type-A\nx1 USB 3.2 Gen 2 Type-C\nx1 Network (RJ-45)\nKeyboard Backlight\n\u0411\u0435\u0437 \u043e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0435\u043d \u0441\u0438\u0441\u0442\u0435\u043c\n\u0411\u0430\u0442\u0435\u0440\u0438\u0458\u0430:5.5h, 3-cell , Lithium Ion (Li-Ion)\n\u0410\u0434\u0430\u043f\u0442\u0435\u0440: 135W"], "category": "gaming_laptopi"}
# {"url": "https://www.neptun.mk/categories/gaming_laptopi/ACER-Nitro-5-AN515-46-R0DK-R7-6800H-16GB-DDR5-512GB-RTX-3050-4GB", "title": "", "warranty": "24", "regular_price": "63.999", "happy_price": "60.999", "description": ["\u041b\u0430\u043f\u0442\u043e\u043f\n\u0414\u0438\u0441\u043f\u043b\u0435\u0458:15.6\" (39.6cm)\n\u0420\u0435\u0437\u043e\u043b\u0443\u0446\u0438\u0458\u0430:(1920x1080) FHD IPS 144Hz SlimBezel\n\u041f\u0440\u043e\u0446\u0435\u0441\u043e\u0440:AMD Ryzen\u2122 7 6800H (8C, 16T, 3.2 - 4.7GHz, L3 16MB)\n\u0413\u0440\u0430\u0444\u0438\u043a\u0430:NVIDIA\u00ae GeForce RTX\u2122 3050 4G-GDDR6\nRAM \u043c\u0435\u043c\u043e\u0440\u0438\u0458\u0430:16 GB DDR5\n\u0414\u0438\u0441\u043a (Storage):512GB PCIe NVMe SED SSD\n\u0411\u0435\u0437 \u043e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0435\u043d \u0441\u0438\u0441\u0442\u0435\u043c\n\u041a\u0430\u043c\u0435\u0440\u0430: HD USB Camera\nWI-FI 6E\nBluetooth 5.2\n57Wh Li-ion battery\nPower:230W"], "category": "gaming_laptopi"}
# {"url": "https://www.neptun.mk/categories/gaming_laptopi/ACER-Nitro-5-AN515-46-R3WL-R7-6800H-16GB-DDR5-512GB-RTX-3070Ti-8GB", "title": "\u041b\u0410\u041f\u0422\u041e\u041f ACER NITRO 5 AN515-46-R3WL R7-6800H/16GB DDR5/512GB/RTX 3070TI 8GB", "warranty": "48", "regular_price": "84.999", "happy_price": "70.999", "description": ["\u041b\u0430\u043f\u0442\u043e\u043f\n\u0414\u0438\u0441\u043f\u043b\u0435\u0458:15.6\" (39.6cm)\n\u0420\u0435\u0437\u043e\u043b\u0443\u0446\u0438\u0458\u0430:(1920x1080) FHD IPS 144Hz\n\u041f\u0440\u043e\u0446\u0435\u0441\u043e\u0440:AMD Ryzen 7 6800H, 3.20-4.70 GHz, 16 MB Cache\n\u0413\u0440\u0430\u0444\u0438\u043a\u0430:NVIDIA\u00ae GeForce RTX\u2122 3070 Ti 8GB GDDR6\nRAM \u043c\u0435\u043c\u043e\u0440\u0438\u0458\u0430:16GB DDR5\n\u0414\u0438\u0441\u043a (Storage):512GB  NVMe SSD\n\u041c\u0440\u0435\u0436\u043d\u0430 \u043a\u0430\u0440\u0442\u0438\u0446\u0430: Killer\u2122 Ethernet E2600, 10/100/1000 GBit\n\u0411\u0435\u0437 \u043e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0435\u043d \u0441\u0438\u0441\u0442\u0435\u043c\n\u041a\u0430\u043c\u0435\u0440\u0430: HD USB Camera\nWi-Fi 6E Wireless LAN\nWireless 802.11 a/b/g/n/ac/ax\nBand: 2.4 GHz, 5 GHz, and 6 GHz\n2x2 MU-MIMO technology\nBluetooth 5.2\n1 x HDMI\n1 x USB Type-C\u2122 port (USB 3.2 / 4)\n2 x USB 3.2 Gen\n1 x USB 3.2 Gen 2 port with power-off charging\n\u041a\u0430\u043c\u0435\u0440\u0430: 720p HD video at 30 fps with Temporal Noise Reduction\nDual Mic (33 mm + 33 mm)\n\u0411\u0430\u0442\u0435\u0440\u0438\u0458\u0430: 4 Cell Li-Ion Battery, 57.5WhCell\n\u0422\u0435\u0436\u0438\u043d\u0430"], "category": "gaming_laptopi"}
# {"url": "https://www.neptun.mk/categories/gaming_laptopi/ACER-Nitro-5-AN515-46-R950-R5-6600H-16GB-DDR5-512GB-RTX-3050-4GB", "title": "\u041b\u0410\u041f\u0422\u041e\u041f \u0410CER NITRO 5 AN515-46-R950 R5-6600H/16GB/512GB/RTX 3050", "warranty": "24", "regular_price": "57.999", "happy_price": "54.999", "description": ["\u041b\u0430\u043f\u0442\u043e\u043f\n\u0414\u0438\u0441\u043f\u043b\u0435\u0458:15.6\" (39.6cm)\n\u0420\u0435\u0437\u043e\u043b\u0443\u0446\u0438\u0458\u0430:(1920x1080) FHD IPS 144Hz SlimBezel\n\u041f\u0440\u043e\u0446\u0435\u0441\u043e\u0440:AMD Ryzen\u2122 5 6600H (6C, 12T, 3.3 - 4.5GHz, L3 16MB)\n\u0413\u0440\u0430\u0444\u0438\u043a\u0430:NVIDIA\u00ae GeForce RTX\u2122 3050 4G-GDDR6\nRAM \u043c\u0435\u043c\u043e\u0440\u0438\u0458\u0430:16 GB DDR5\n\u0414\u0438\u0441\u043a (Storage):512GB PCIe NVMe SED SSD\n\u0411\u0435\u0437 \u043e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0435\u043d \u0441\u0438\u0441\u0442\u0435\u043c\n\u041a\u0430\u043c\u0435\u0440\u0430: HD USB Camera\nWI-FI 6E\nBluetooth 5.2\n57Wh Li-ion battery\nPower:230W"], "category": "gaming_laptopi"}
# {"url": "https://www.neptun.mk/categories/gaming_laptopi/ACER-Nitro-5-AN515-47-R0A1-R5-7535HS-16GB-DDR5-512GB-RTX-3050-4GB", "title": "\u041b\u0410\u041f\u0422\u041e\u041f ACER NITRO 5 AN515-47-R0A1 R5-7535HS/16GB DDR5/512GB/RTX 3050 4GB", "warranty": "24", "regular_price": "69.999", "happy_price": "60.999", "description": ["\u041b\u0430\u043f\u0442\u043e\u043f\n\u0414\u0438\u0441\u043f\u043b\u0435\u0458:15.6\" (39.6cm)\n\u0420\u0435\u0437\u043e\u043b\u0443\u0446\u0438\u0458\u0430:(1920x1080) FHD IPS 144Hz SlimBezel\n\u041f\u0440\u043e\u0446\u0435\u0441\u043e\u0440:AMD Ryzen\u2122 5 7535HS (6C, 12T, 3.3 GHz-4.55 GHz, L3 16MB)\n\u0413\u0440\u0430\u0444\u0438\u043a\u0430:NVIDIA\u00ae GeForce RTX\u2122 3050 4G-GDDR6(2C*256*16*4)\nRAM \u043c\u0435\u043c\u043e\u0440\u0438\u0458\u0430:16 GB DDR5\n\u0414\u0438\u0441\u043a (Storage):512GB PCIe NVMe SED SSD\n\u0411\u0435\u0437 \u043e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0435\u043d \u0441\u0438\u0441\u0442\u0435\u043c\n\u041a\u0430\u043c\u0435\u0440\u0430: HD USB Camera\nWI-FI 6E\nBluetooth\n57Wh Li-ion battery\nPower:180W"], "category": "gaming_laptopi"}
# {"url": "https://www.neptun.mk/categories/gaming_laptopi/ACER-Nitro-5-AN515-47-R4CG-R7-7735HS-16GB-DDR5-512GB-RTX-3050-4GB", "title": "", "warranty": "24", "regular_price": "75.999", "happy_price": "65.999", "description": ["\u041b\u0430\u043f\u0442\u043e\u043f\n\u0414\u0438\u0441\u043f\u043b\u0435\u0458:15.6\" (39.6cm)\n\u0420\u0435\u0437\u043e\u043b\u0443\u0446\u0438\u0458\u0430:(1920x1080) FHD IPS 144Hz SlimBezel\n\u041f\u0440\u043e\u0446\u0435\u0441\u043e\u0440:AMD Ryzen\u2122 7 7735HS (8C, 16T, 3.2 GHz-4.75 GHz, L3 16MB)\n\u0413\u0440\u0430\u0444\u0438\u043a\u0430:NVIDIA\u00ae GeForce RTX\u2122 3050 4G-GDDR6(2C*256*16*4)\nRAM \u043c\u0435\u043c\u043e\u0440\u0438\u0458\u0430:16 GB DDR5\n\u0414\u0438\u0441\u043a (Storage):512GB PCIe NVMe SED SSD\n\u0411\u0435\u0437 \u043e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0435\u043d \u0441\u0438\u0441\u0442\u0435\u043c\n\u041a\u0430\u043c\u0435\u0440\u0430: HD USB Camera\nWI-FI 6E\nBluetooth\n57Wh Li-ion battery\nPower:180W"], "category": "gaming_laptopi"}
# {"url": "https://www.neptun.mk/categories/gaming_laptopi/ACER-Nitro-5-AN517-54-79DQ-17-3--i7-11600H-32GB-512GB-SSD-RTX-3050-4GB", "title": "\u041b\u0410\u041f\u0422\u041e\u041f ACER NITRO 5 AN517-54-79DQ 17.3\" I7-11600H/32GB/512GB SSD/RTX 3050 4GB", "warranty": "24", "regular_price": "60.999", "happy_price": "56.999", "description": ["\u041b\u0430\u043f\u0442\u043e\u043f\n\u0414\u0438\u0441\u043f\u043b\u0435\u0458:17.3\" (43.9cm)\n\u0420\u0435\u0437\u043e\u043b\u0443\u0446\u0438\u0458\u0430:FHD (1920 x 1080) FHD, IPS, 144Hz, 250 cd/m\u00b2\n\u041f\u0440\u043e\u0446\u0435\u0441\u043e\u0440:Intel\u00ae Core\u2122 i7-11600H Hexa-core (6 Core\u2122, 4.60 GHz, 18 MB cache)\n\u0413\u0440\u0430\u0444\u0438\u043a\u0430:NVIDIA\u00ae GeForce RTX\u2122 3050 4GB GDDR6\nRAM \u043c\u0435\u043c\u043e\u0440\u0438\u0458\u0430:32 GB DDR4 3200MHz\n\u0414\u0438\u0441\u043a (Storage): 512GB PCIe NVMe M.2 SSD\n\u0411\u0435\u0437 \u043e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0435\u043d \u0441\u0438\u0441\u0442\u0435\u043c\nWIFI IEEE 802.11ax\nBluetooth 5.1\nHD WEB CAM\n\u0417\u0432\u0443\u0447\u043d\u0438\u0446\u0438 \u04452\n\u041c\u0438\u043a\u0440\u043e\u0444\u043e\u043d\u0438 \u04452\n\u041f\u0440\u0438\u043a\u043b\u0443\u0447\u043e\u0446\u0438:\nHDMI x1\nNetwork (RJ-45) x1\nAudio Line Out\nUSB x4\nRed Backlight\n\u0411\u0430\u0442\u0435\u0440\u0438\u0458\u0430:57Wh Lithium Polymer (Li-Polymer)\n\u0412\u0440\u0435\u043c\u0435 \u043d\u0430 \u0440\u0430\u0431\u043e\u0442\u0430: \u0434\u043e 8h\n180W AC Adapter"], "category": "gaming_laptopi"}
# {"url": "https://www.neptun.mk/categories/gaming_laptopi/ACER-Nitro-5-AN517-54-79HS-17-3--i7-11600H-16GB-512GB-SSD-RTX-3050-4GB", "title": "\u041b\u0410\u041f\u0422\u041e\u041f ACER NITRO 5 AN517-54-79HS 17.3\" I7-11600H/16GB/512GB SSD/RTX 3050 4GB", "warranty": "24", "regular_price": "57.999", "happy_price": "50.999", "description": ["\u041b\u0430\u043f\u0442\u043e\u043f\n\u0414\u0438\u0441\u043f\u043b\u0435\u0458:17.3\" (43.9cm)\n\u0420\u0435\u0437\u043e\u043b\u0443\u0446\u0438\u0458\u0430:FHD (1920 x 1080) FHD, IPS, 144Hz, 250 cd/m\u00b2\n\u041f\u0440\u043e\u0446\u0435\u0441\u043e\u0440:Intel\u00ae Core\u2122 i7-11600H Hexa-core (6 Core\u2122, 4.60 GHz, 18 MB cache)\n\u0413\u0440\u0430\u0444\u0438\u043a\u0430:NVIDIA\u00ae GeForce RTX\u2122 3050 4GB GDDR6\nRAM \u043c\u0435\u043c\u043e\u0440\u0438\u0458\u0430:16 GB DDR4 3200MHz\n\u0414\u0438\u0441\u043a (Storage): 512GB PCIe NVMe M.2 SSD\n\u0411\u0435\u0437 \u043e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0435\u043d \u0441\u0438\u0441\u0442\u0435\u043c\nWIFI IEEE 802.11ax\nBluetooth 5.1\nHD WEB CAM\n\u0417\u0432\u0443\u0447\u043d\u0438\u0446\u0438 \u04452\n\u041c\u0438\u043a\u0440\u043e\u0444\u043e\u043d\u0438 \u04452\n\u041f\u0440\u0438\u043a\u043b\u0443\u0447\u043e\u0446\u0438:\nHDMI x1\nNetwork (RJ-45) x1\nAudio Line Out\nUSB x4\nRed Backlight\n\u0411\u0430\u0442\u0435\u0440\u0438\u0458\u0430:57Wh Lithium Polymer (Li-Polymer)\n\u0412\u0440\u0435\u043c\u0435 \u043d\u0430 \u0440\u0430\u0431\u043e\u0442\u0430: \u0434\u043e 8h\n180W AC Adapter"], "category": "gaming_laptopi"}
# {"url": "https://www.neptun.mk/categories/gaming_laptopi/ACER-Nitro-5-AN517-55-52JQ-17-3--i5-12500H-16GB-512GB-RTX-3050-4GB", "title": "", "warranty": "24", "regular_price": "62.999", "happy_price": "59.999", "description": ["\u041b\u0430\u043f\u0442\u043e\u043f\n\u0414\u0438\u0441\u043f\u043b\u0435\u0458:17.3\" (43.9cm)\n\u0420\u0435\u0437\u043e\u043b\u0443\u0446\u0438\u0458\u0430:FHD (1920 x 1080) FHD IPS 144Hz SlimBezel\n\u041f\u0440\u043e\u0446\u0435\u0441\u043e\u0440:Intel\u00ae Core\u2122 i5-12500H (12-core/16-thread, 18MB cache, up to 4.5 GHz max boost)\n\u0413\u0440\u0430\u0444\u0438\u043a\u0430:NVIDIA\u00ae GeForce RTX\u2122 3050 4GB\nRAM \u043c\u0435\u043c\u043e\u0440\u0438\u0458\u0430:16 GB DDR5 5600MHz\n\u0414\u0438\u0441\u043a (Storage): 512GB PCIe NVMe SED SSD\n\u0411\u0435\u0437 \u043e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0435\u043d \u0441\u0438\u0441\u0442\u0435\u043c\nLAN 10/100/1000/2500 Mbps\nWIFI6E+BT\nFHD USB Camera\n\u0411\u0430\u0442\u0435\u0440\u0438\u0458\u0430:90Wh Li-ion battery\n330W AC Adapter"], "category": "gaming_laptopi"}
# {"url": "https://www.neptun.mk/categories/gaming_laptopi/ACER-Nitro-5-AN517-55-5834-17-3--i5-12500H-16GB-512GB-RTX-3050-4GB", "title": "", "warranty": "24", "regular_price": "65.999", "happy_price": "59.999", "description": ["\u041b\u0430\u043f\u0442\u043e\u043f\n\u0414\u0438\u0441\u043f\u043b\u0435\u0458:17.3\" (43.9 cm)\n\u0420\u0435\u0437\u043e\u043b\u0443\u0446\u0438\u0458\u0430:(1920 x 1080) FHD IPS 144Hz SlimBezel\n\u041f\u0440\u043e\u0446\u0435\u0441\u043e\u0440:Intel\u00ae Core\u2122 i5-12500H\n\u0413\u0440\u0430\u0444\u0438\u043a\u0430:NVIDIA\u00ae GeForce RTX\u2122 3050 4GB GDDR6\nRAM \u041c\u0435\u043c\u043e\u0440\u0438\u0458\u0430: 16 GB DDR4 3200MHz\n\u0414\u0438\u0441\u043a (Storage): 512GB PCIe NVMe SED SSD\n\u0411\u0435\u0437 \u043e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0435\u043d \u0441\u0438\u0441\u0442\u0435\u043c\nWireless:802.11AX + BT\n\u041a\u0430\u043c\u0435\u0440\u0430:HD USB C\u00e2mera\n\u0411\u0430\u0442\u0435\u0440\u0438\u0458\u0430:90Wh Li-ion\n\u041f\u043e\u043b\u043d\u0430\u0447: 180W"], "category": "gaming_laptopi"}
# {"url": "https://www.neptun.mk/categories/gaming_laptopi/ACER-Nitro-5-AN517-55-73PG-17-3--i7-12700H-16GB-512GB-RTX-3060-6GB", "title": "ACER NITRO 5 AN517-55-73PG 17.3\" I7-12700H/16GB/512GB/RTX 3060 6GB", "warranty": "24", "regular_price": "88.999", "happy_price": "81.999", "description": ["\u041b\u0430\u043f\u0442\u043e\u043f\n\u0414\u0438\u0441\u043f\u043b\u0435\u0458:17.3\" (43.9cm)\n\u0420\u0435\u0437\u043e\u043b\u0443\u0446\u0438\u0458\u0430:(1920 x 1080) FHD LED 144 Hz\n\u041f\u0440\u043e\u0446\u0435\u0441\u043e\u0440:Intel Core i7-12700H (up to 4.7 GHz, 24 MB Intel\u00ae Smart Cache, 14 cores, 20 threads)\n\u0413\u0440\u0430\u0444\u0438\u043a\u0430:NVIDIA\u00ae GeForce\u00ae RTX\u2122 3060  6GB GDDR6\nRAM \u043c\u0435\u043c\u043e\u0440\u0438\u0458\u0430:16 GB\n\u0414\u0438\u0441\u043a (Storage):512GB SSD\n\u0411\u0435\u0437 \u043e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0435\u043d \u0441\u0438\u0441\u0442\u0435\u043c\nWLAN:IEEE 802.11 a/b/g/n/ac/ax\nBluetooth 5.2\nGigabit Ethernet\n\u041c\u0438\u043a\u0440\u043e\u0444\u043e\u043d\n\u041a\u043e\u043d\u0435\u043a\u0446\u0438\u0458\u0430:\n1 x HDMI\n1 x USB 3.2 Gen 1 \u0442\u0438\u043f A\n2 x USB 3.2 Gen 2 \u0442\u0438\u043f A\n1 x USB 3.2 Gen 2 \u0442\u0438\u043f C\n1 x RJ-45\n\u0411\u0430\u0442\u0435\u0440\u0438\u0458\u0430:4 cell - Li-Ion\nPower:90 W"], "category": "gaming_laptopi"}
# {"url": "https://www.neptun.mk/categories/gaming_laptopi/ACER-Predator-Helios-300-PH315-55-70W2-i7-12700H-16GB-DDR5-512GB-RTX-3070Ti-8GB", "title": "", "warranty": "24", "regular_price": "105.999", "happy_price": "96.999", "description": ["\u041b\u0430\u043f\u0442\u043e\u043f\n\u0414\u0438\u0441\u043f\u043b\u0435\u0458:15.6\" (39.6cm)\n\u0420\u0435\u0437\u043e\u043b\u0443\u0446\u0438\u0458\u0430:FHD (1920 x 1080) FHD IPS 165Hz SlimBezel\n\u041f\u0440\u043e\u0446\u0435\u0441\u043e\u0440:Intel\u00ae Core\u2122 i7-12700H (14-core/20-thread, 24MB cache, up to 4.7 GHz max boost)\n\u0413\u0440\u0430\u0444\u0438\u043a\u0430:NVIDIA\u00ae GeForce RTX\u2122 3070 Ti 8GB\nRAM \u043c\u0435\u043c\u043e\u0440\u0438\u0458\u0430:16 GB DDR5\n\u0414\u0438\u0441\u043a (Storage): 512GB PCIe NVMe SED SSD\n\u0411\u0435\u0437 \u043e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0435\u043d \u0441\u0438\u0441\u0442\u0435\u043c\nLAN 10/100/1000/2500 Mbps\nWIFI6E+BT\nFHD USB Camera\n\u0411\u0430\u0442\u0435\u0440\u0438\u0458\u0430:90Wh Li-ion battery\n280W AC Adapter"], "category": "gaming_laptopi"}
# {"url": "https://www.neptun.mk/categories/gaming_laptopi/ACER-Predator-Helios-300-PH315-55-9562-i9-12900H-16GB-DDR5-1TB-RTX-3070Ti-8GB", "title": "\u041b\u0410\u041f\u0422\u041e\u041f ACER PREDATOR HELIOS 300 PH315-55-9562 I9-12900H/16GB/1TB/RTX 3070TI 8GB", "warranty": "24", "regular_price": "114.999", "happy_price": "103.999", "description": ["\u041b\u0430\u043f\u0442\u043e\u043f\n\u0414\u0438\u0441\u043f\u043b\u0435\u0458:15.6\" (39.6cm)\n\u0420\u0435\u0437\u043e\u043b\u0443\u0446\u0438\u0458\u0430:FHD (1920 x 1080) FHD IPS 165Hz SlimBezel\n\u041f\u0440\u043e\u0446\u0435\u0441\u043e\u0440:Intel\u00ae Core\u2122 i9-12900H (14-core/20-thread, 24MB cache, up to 5.0 GHz max boost)\n\u0413\u0440\u0430\u0444\u0438\u043a\u0430:NVIDIA\u00ae GeForce RTX\u2122 3070 Ti 8GB\nRAM \u043c\u0435\u043c\u043e\u0440\u0438\u0458\u0430:16 GB DDR5\n\u0414\u0438\u0441\u043a (Storage): 1TB PCIe NVMe SED SSD\n\u0411\u0435\u0437 \u043e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0435\u043d \u0441\u0438\u0441\u0442\u0435\u043c\nLAN 10/100/1000/2500 Mbps\nWIFI6E+BT\nFHD USB Camera\n\u0411\u0430\u0442\u0435\u0440\u0438\u0458\u0430:90Wh Li-ion battery\n280W AC Adapter"], "category": "gaming_laptopi"}
# {"url": "https://www.neptun.mk/categories/gaming_laptopi/ACER-Predator-Helios-300-PH315-55-95CR-i9-12900H-16GB-DDR5-1TB-RTX-3070-8GB", "title": "", "warranty": "24", "regular_price": "92.999", "happy_price": "76.999", "description": ["\u041b\u0430\u043f\u0442\u043e\u043f\n\u0414\u0438\u0441\u043f\u043b\u0435\u0458:Acer ComfyView\u2122 15.6\" (39.6 cm)\n\u0420\u0435\u0437\u043e\u043b\u0443\u0446\u0438\u0458\u0430:(1920 x 1080) FHD, IPS, 165Hz, NVIDIA G-SYNC\u2122\n\u041f\u0440\u043e\u0446\u0435\u0441\u043e\u0440: 12th Gen Intel\u00ae Core\u2122 i9-12900H, 14 Core\u2122, 24MB\n\u0413\u0440\u0430\u0444\u0438\u043a\u0430:NVIDIA\u00ae GeForce\u00ae RTX\u2122 3070 8 GB GDDR6 VRAM\nRAM \u043c\u0435\u043c\u043e\u0440\u0438\u0458\u0430: 16GB DDR5 (1 x 16)\n\u0414\u0438\u0441\u043a (Storage):1TB SSD PCIe\n\u0411\u0435\u0437 \u043e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0435\u043d \u0441\u0438\u0441\u0442\u0435\u043c\n\u041f\u043e\u0440\u0442\u0438:\n1x (HDMI 2.1 with HDCP support)\n2x DisplayPort\u2122 (1xMiniDispalyPort)\n1x via USB Type-C) Thunderbolt Thunderbolt\u2122 4 (via USB Type-C) USB 3.2\n4x (1x USB Type -C Gen2)\n1x Gen2 (mit Power-Off USB Charging)\n2x Gen1\nEthernet (RJ-45)\n1x headphone/speaker jack\nLAN: Killer\u2122 Ethernet E2600\nIntel\u00ae Killer\u2122 Wireless Wi-Fi 6E\nBluetooth\u00ae 5.2\nKeyboard Backlight\n\u0410\u0443\u0434\u0438\u043e: Acer TrueHarmony\n\u0412\u0433\u0440\u0430\u0434\u0435\u043d\u0438 \u0437\u0432\u0443\u0447\u043d\u0438\u0446\u0438\n\u0412\u0433\u0440\u0430\u0434\u0435\u043d \u043c\u0438\u043a\u0440\u043e\u0444\u043e\u043d\n\u0411\u0430\u0442\u0435\u0440\u0438\u0458\u0430:90Wh Li-ion 4-cell battery\nPower:280 W\n\u0422\u0435\u0436\u0438\u043d\u0430: 2.6kg"], "category": "gaming_laptopi"}
# {"url": "https://www.neptun.mk/categories/gaming_laptopi/ACER-Predator-Helios-300-PH315-55-96NA-i9-12900H-32GB-DDR5-1TB-RTX-3070-8GB", "title": "\u041b\u0410\u041f\u0422\u041e\u041f ACER PREDATOR HELIOS 300 PH315-55-96NA I9-12900H/32GB DDR5/1TB/RTX 3070 8GB", "warranty": "24", "regular_price": "97.999", "happy_price": "81.999", "description": ["\u041b\u0430\u043f\u0442\u043e\u043f\n\u0414\u0438\u0441\u043f\u043b\u0435\u0458:Acer ComfyView\u2122 15.6\" (39.6 cm)\n\u0420\u0435\u0437\u043e\u043b\u0443\u0446\u0438\u0458\u0430:(1920 x 1080) FHD, IPS, 165Hz, NVIDIA G-SYNC\u2122\n\u041f\u0440\u043e\u0446\u0435\u0441\u043e\u0440: 12th Gen Intel\u00ae Core\u2122 i9-12900H 2.50 GHz, 14 Core\u2122\n\u0413\u0440\u0430\u0444\u0438\u043a\u0430:NVIDIA\u00ae GeForce\u00ae RTX\u2122 3070 8 GB GDDR6 VRAM\nRAM \u043c\u0435\u043c\u043e\u0440\u0438\u0458\u0430: 32GB DDR5 (2 x 16GB)\n\u0414\u0438\u0441\u043a (Storage):1TB SSD PCIe\n\u0411\u0435\u0437 \u043e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0435\u043d \u0441\u0438\u0441\u0442\u0435\u043c\n\u041f\u043e\u0440\u0442\u0438:\n1x (HDMI 2.1 with HDCP support)\n2x DisplayPort\u2122 (1xMiniDispalyPort)\n1x via USB Type-C) Thunderbolt Thunderbolt\u2122 4 (via USB Type-C) USB 3.2\n4x (1x USB Type -C Gen2)\n1x Gen2 (mit Power-Off USB Charging)\n2x Gen1\nEthernet (RJ-45)\n1x headphone/speaker jack\nLAN: Killer\u2122 Ethernet E2600\nIntel\u00ae Killer\u2122 Wireless Wi-Fi 6E\nBluetooth\u00ae 5.2\nKeyboard Backlight\n\u0410\u0443\u0434\u0438\u043e: Acer TrueHarmony\n\u0412\u0433\u0440\u0430\u0434\u0435\u043d\u0438 \u0437\u0432\u0443\u0447\u043d\u0438\u0446\u0438\n\u0412\u0433\u0440\u0430\u0434\u0435\u043d \u043c\u0438\u043a\u0440\u043e\u0444\u043e\u043d\n\u0411\u0430\u0442\u0435\u0440\u0438\u0458\u0430:90Wh Li-ion 4-cell battery\nPower:280 W\n\u0422\u0435\u0436\u0438\u043d\u0430: 2.6kg"], "category": "gaming_laptopi"}
# {"url": "https://www.neptun.mk/categories/gaming_laptopi/ASUS-GU603ZM-K8029W-16--i7-12700H-16GB-512GB-RTX-3060-6GB", "title": "\u041b\u0410\u041f\u0422\u041e\u041f ASUS ROG ZEPHYRUS M16 GU603ZM-K8029W 16\" I7-12700H/16GB/512GB/RTX 3060 6GB", "warranty": "24", "regular_price": "134.999", "happy_price": "89.999", "description": ["\u041b\u0430\u043f\u0442\u043e\u043f\n\u0414\u0438\u0441\u043f\u043b\u0435\u0458:16.0\" (40.6cm)\n\u0420\u0435\u0437\u043e\u043b\u0443\u0446\u0438\u0458\u0430:(2560 x 1600) WQXGA IPS 165Hz\n\u041f\u0440\u043e\u0446\u0435\u0441\u043e\u0440:Intel Core i7-12700H (TBD)\n\u0413\u0440\u0430\u0444\u0438\u043a\u0430:Nvidia Geforce RTX 3060 6GB\nRAM \u043c\u0435\u043c\u043e\u0440\u0438\u0458\u0430:16GB DDR4\n\u0414\u0438\u0441\u043a (Storage):512 SSD\n\u041e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0435\u043d \u0441\u0438\u0441\u0442\u0435\u043c:Windows 11 Home\nLAN 10/100/1000 Mbps\nWi-Fi 6E(802.11ax)+Bluetooth 5.2 (Dual band) 2*2\n\u041f\u043e\u0440\u0442\u0438:\n1 x RJ45\n1 x Thunderbolt 4 support Display port\n1 x USB 3.2 Gen 2 Type-C\n2 x USB 3.2 Gen 2 Type-A\n1 x card reader (microSD)\n1 x 3.5mm Combo Audio Jack\n1 x HDMI 2.0b\n\u0412\u0433\u0430\u0434\u0435\u043d \u043c\u0438\u043a\u0440\u043e\u0444\u043e\u043d\n\u041e\u0441\u0432\u0435\u0442\u043b\u0435\u043d\u0430 \u0442\u0430\u0441\u0442\u0430\u0442\u0443\u0440\u0430 RGB\n\u0417\u0432\u0443\u0447\u043d\u0438\u043a:2x 2W speaker\n\u0410\u0443\u0434\u0438\u043e:Tech AI noise-canceling - Dolby Atmos\nSecurity BIOS Administrator Password and User Password Protection\n\u0411\u0430\u0442\u0435\u0440\u0438\u0458\u0430:90WHrs, 4S1P, 4-cell Li-ion"], "category": "gaming_laptopi"}
# {"url": "https://www.neptun.mk/categories/gaming_laptopi/ASUS-ROG-Strix-G16-G614JI-N3093-16--i7-13650HX-16GB-DDR5-1TB-RTX-4070-8GB", "title": "", "warranty": "24", "regular_price": "114.999", "happy_price": "105.999", "description": ["\u041b\u0430\u043f\u0442\u043e\u043f\n\u0414\u0438\u0441\u043f\u043b\u0435\u0458:16'' (40.6cm)\n\u0420\u0435\u0437\u043e\u043b\u0443\u0446\u0438\u0458\u0430:(1920 x 1200) WUXGA, IPS, 165Hz\n\u041f\u0440\u043e\u0446\u0435\u0441\u043e\u0440:Intel Core i7-13650HX, 2.6 GHz 24M Cache, up to 4.9 GHz, 14 cores\n\u0413\u0440\u0430\u0444\u0438\u043a\u0430:NVIDIA GeForce RTX 4070 8GB GDDR6\nNVIDIA G-Sync\nRAM \u041c\u0435\u043c\u043e\u0440\u0438\u0458\u0430:16GB DDR5\n\u0414\u0438\u0441\u043a (Storage):1TB PCIe 4.0 NVMe M.2 SSD\n\u0411\u0435\u0437 \u043e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0435\u043d \u0441\u0438\u0441\u0442\u0435\u043c\nLAN 10/100/1000 Mbps\nWi-Fi 6E(802.11ax) (Triple band) 2*2 + Bluetooth 5.2\n\u041f\u043e\u0440\u0442\u0438:\n1x RJ45 LAN port\n1x Thunderbolt 4 support DisplayPort\n1x USB 3.2 Gen 2 Type-C support DisplayPort / power delivery / G-SYNC\n2x USB 3.2 Gen 2 Type-A\n1x HDMI 2.1 FRL\n1x 3.5mm Combo Audio Jack\n720P HD camera\n\u0412\u0433\u0430\u0434\u0435\u043d \u043c\u0438\u043a\u0440\u043e\u0444\u043e\u043d\nBacklit Chiclet Keyboard 4-Zone RGB\n\u0417\u0432\u0443\u0447\u043d\u0438\u043a:\u0441\u0438\u0441\u0442\u0435\u043c \u0441\u043e 2 \u0437\u0432\u0443\u0447\u043d\u0438\u0446\u0438 \u0441\u043e Smart Amplifier Technology\n\u0410\u0443\u0434\u0438\u043e:\nTech AI noise-canceling\nDolby Atmos\nHi-Res certification\nAI noise-canceling technology\nDolby Atmos\nSmart Amp Technology\nSecurity BIOS Administrator Password and User Password Protection\n\u0411\u0430\u0442\u0435\u0440\u0438\u0458\u0430:90WHrs, 4S1P, 4-cell Li-ion\n\u0410\u0434\u0430\u043f\u0442\u0435\u0440: 280W"], "category": "gaming_laptopi"}
# {"url": "https://www.neptun.mk/categories/gaming_laptopi/ASUS-ROG-Strix-G16-G614JU-N3092-16--i5-13450HX-16GB-DDR5-512GB-RTX-4050-6GB", "title": "\u041b\u0410\u041f\u0422\u041e\u041f ASUS ROG STRIX G16 G614JU-N3092 16\" I5-13450HX/16GB DDR5/512GB/RTX 4050 6GB", "warranty": "24", "regular_price": "80.999", "happy_price": "73.999", "description": ["\u041b\u0430\u043f\u0442\u043e\u043f\n\u0414\u0438\u0441\u043f\u043b\u0435\u0458:16.0\" (40.6cm)\n\u0420\u0435\u0437\u043e\u043b\u0443\u0446\u0438\u0458\u0430:(1920 x 1200) FHD+, IPS, 160Hz, G-Sync\n\u041f\u0440\u043e\u0446\u0435\u0441\u043e\u0440:13th Gen Intel Core i5-13450HX Processor 2.4 GHz (20M Cache, up to 4.6 GHz, 10 cores: 6 P-cores)\n\u0413\u0440\u0430\u0444\u0438\u043a\u0430:NVIDIA GeForce RTX 4050 6GB GDDR6\nRAM \u041c\u0435\u043c\u043e\u0440\u0438\u0458\u0430:16GB DDR5-4800\n\u0414\u0438\u0441\u043a (Storage):512GB PCIe 4.0 NVMe M.2 SSD\n\u0411\u0435\u0437 \u043e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0435\u043d \u0441\u0438\u0441\u0442\u0435\u043c\nLAN 10/100/1000 Mbps\nWi-Fi 6E(802.11ax) (Triple band) 2*2 + Bluetooth 5.3\n\u041f\u043e\u0440\u0442\u0438:\n1x RJ45 LAN port\n1x Thunderbolt 4 support DisplayPort\n1x USB 3.2 Gen 2 Type-C support DisplayPort / power delivery / G-SYNC\n2x USB 3.2 Gen 2 Type-A\n1x HDMI 2.1 FRL\n1x 3.5mm Combo Audio Jack\n720P HD camera\n\u0412\u0433\u0430\u0434\u0435\u043d \u043c\u0438\u043a\u0440\u043e\u0444\u043e\u043d\n\u041e\u0441\u0432\u0435\u0442\u043b\u0435\u043d\u0430 \u0442\u0430\u0441\u0442\u0430\u0442\u0443\u0440\u0430: Backlit Chiclet Keyboard 4-Zone RGB\n2x \u0437\u0432\u0443\u0447\u043d\u0438\u0446\u0438 \u0441\u043e Smart Amplifier \u0442\u0435\u0445\u043d\u043e\u043b\u043e\u0433\u0438\u0458\u0430\n\u0410\u0443\u0434\u0438\u043e:Tech AI noise-canceling - Dolby Atmos\nSecurity BIOS Administrator Password and User Password Protection\n\u0411\u0430\u0442\u0435\u0440\u0438\u0458\u0430:90WHrs, 4S1P, 4-cell Li-ion\n280W AC Adapter"], "category": "gaming_laptopi"}
# {"url": "https://www.neptun.mk/categories/gaming_laptopi/ASUS-ROG-Strix-G16-G614JU-N3170-16--i5-13450HX-16GB-DDR5-1TB-RTX-4050-6GB", "title": "\u041b\u0410\u041f\u0422\u041e\u041f ASUS ROG STRIX G16 G614JU-N3170 16\" I5-13450HX/16GB DDR5/1TB/RTX 4050 6GB", "warranty": "24", "regular_price": "83.999", "happy_price": "71.999", "description": ["\u041b\u0430\u043f\u0442\u043e\u043f\n\u0414\u0438\u0441\u043f\u043b\u0435\u0458:16'' (40.6cm)\n\u0420\u0435\u0437\u043e\u043b\u0443\u0446\u0438\u0458\u0430:(1920 x 1200) WUXGA, IPS, 165Hz\n\u041f\u0440\u043e\u0446\u0435\u0441\u043e\u0440:Intel Core i5-13450HX Processor 2.4 GHz (20M Cache, up to 4.6 GHz, 10 cores)\n\u0413\u0440\u0430\u0444\u0438\u043a\u0430:NVIDIA GeForce RTX 4050 Laptop GPU 6GB GDDR6\nNVIDIA G-Sync\nRAM \u041c\u0435\u043c\u043e\u0440\u0438\u0458\u0430:16GB DDR5\n\u0414\u0438\u0441\u043a (Storage):1TB PCIe 4.0 NVMe M.2 SSD\n\u0411\u0435\u0437 \u043e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0435\u043d \u0441\u0438\u0441\u0442\u0435\u043c\nLAN 10/100/1000 Mbps\nWi-Fi 6E(802.11ax) (Triple band) 2*2 + Bluetooth 5.3\n\u041f\u043e\u0440\u0442\u0438:\n1x RJ45 LAN port\n1x Thunderbolt 4 support DisplayPort\n1x USB 3.2 Gen 2 Type-C support\n1x HDMI 2.1 FRL\n1x 3.5mm Combo Audio Jack\n720P HD camera\n\u0412\u0433\u0430\u0434\u0435\u043d \u043c\u0438\u043a\u0440\u043e\u0444\u043e\u043d\nBacklit Chiclet Keyboard 4-Zone RGB\n\u0417\u0432\u0443\u0447\u043d\u0438\u043a:\u0441\u0438\u0441\u0442\u0435\u043c \u0441\u043e 2 \u0437\u0432\u0443\u0447\u043d\u0438\u0446\u0438 \u0441\u043e Smart Amplifier Technology\n\u0410\u0443\u0434\u0438\u043e:\nTech AI noise-canceling\nDolby Atmos\nHi-Res certification\nAI noise-canceling technology\nDolby Atmos\nSmart Amp Technology\nSecurity BIOS Administrator Password and User Password Protection\n\u0411\u0430\u0442\u0435\u0440\u0438\u0458\u0430:90WHrs, 4S1P, 4-cell Li-ion\n\u0411\u0440\u0437\u043e \u043f\u043e\u043b\u043d\u0435\u045a\u0435: 0-50% \u0437\u0430 30 \u043c\u0438\u043d\u0443\u0442\u0438"], "category": "gaming_laptopi"}
# {"url": "https://www.neptun.mk/categories/gaming_laptopi/ASUS-ROG-Strix-G16-G614JU-N3218-16--i7-13650HX-16GB-DDR5-1TB-RTX-4050-6GB-", "title": "\u041b\u0410\u041f\u0422\u041e\u041f ASUS ROG STRIX G16 G614JU-N3218 16\" I7-13650HX/16GB DDR5/1TB/RTX 4050 6GB", "warranty": "24", "regular_price": "84.999", "happy_price": "78.999", "description": ["\u041b\u0430\u043f\u0442\u043e\u043f\n\u0414\u0438\u0441\u043f\u043b\u0435\u0458:16\"(40.6cm)\n\u0420\u0435\u0437\u043e\u043b\u0443\u0446\u0438\u0458\u0430:(1920 x 1200, WUXGA) FHD+, IPS, 165Hz, 7ms\n\u041f\u0440\u043e\u0446\u0435\u0441\u043e\u0440:Intel Core i7-13650HX Processor 2.6 GHz 24M Cache, up to 4.9 GHz, 14 cores: 6 P-cores)\n\u0413\u0440\u0430\u0444\u0438\u043a\u0430:NVIDIA GeForce RTX 4050 6GB GDDR6\nNVIDIA G-Sync\nRAM \u041c\u0435\u043c\u043e\u0440\u0438\u0458\u0430:16GB DDR5\n\u0414\u0438\u0441\u043a (Storage):1TB PCIe 4.0 NVMe M.2 SSD\n\u0411\u0435\u0437 \u043e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0435\u043d \u0441\u0438\u0441\u0442\u0435\u043c\nLAN 10/100/1000 Mbps\nWi-Fi 6E(802.11ax) (Triple band) 2*2\nBluetooth 5.3\n\u041f\u043e\u0440\u0442\u0438:\n1x RJ45 LAN port\n1x Thunderbolt    4 support DisplayPort\n1x USB 3.2 Gen 2 Type-C support DisplayPort    / power delivery / G-SYNC\n2x USB 3.2 Gen 2 Type-A\n1x HDMI 2.1 FRL\n1x 3.5mm Combo Audio Jack\n720P HD camera\n\u0412\u0433\u0430\u0434\u0435\u043d \u043c\u0438\u043a\u0440\u043e\u0444\u043e\u043d\nBacklit Chiclet Keyboard 4-Zone RGB\n\u0417\u0432\u0443\u0447\u043d\u0438\u043a:\u0441\u0438\u0441\u0442\u0435\u043c \u0441\u043e 2 \u0437\u0432\u0443\u0447\u043d\u0438\u0446\u0438 \u0441\u043e Smart Amplifier Technology\n\u0410\u0443\u0434\u0438\u043e:\nAI noise-canceling technology\nDolby Atmos\nHi-Res certification\nSmart Amp Technology\nSupport Microsoft Cortana near field/Far field\nSecurity BIOS Administrator Password and User Password Protection\n\u0411\u0430\u0442\u0435\u0440\u0438\u0458\u0430:90WHrs, 4S1P, 4-cell Li-ion\n\u0411\u0440\u0437\u043e \u043f\u043e\u043b\u043d\u0435\u045a\u0435: 0-50% \u0437\u0430 30 \u043c\u0438\u043d\u0443\u0442\u0438"], "category": "gaming_laptopi"}
# {"url": "https://www.neptun.mk/categories/gaming_laptopi/ASUS-ROG-Strix-G16-G614JV-N3073-16--i5-13450HX-16GB-DDR5-1TB-RTX-4060-8GB-", "title": "\u041b\u0410\u041f\u0422\u041e\u041f ASUS ROG STRIX G16 G614JV-N3073 16\" I5-13450HX/16GB DDR5/1TB/RTX 4060 8GB", "warranty": "24", "regular_price": "89.999", "happy_price": "80.999", "description": ["\u041b\u0430\u043f\u0442\u043e\u043f\n\u0414\u0438\u0441\u043f\u043b\u0435\u0458:16'' (40.6cm)\n\u0420\u0435\u0437\u043e\u043b\u0443\u0446\u0438\u0458\u0430:(1920 x 1200) WUXGA, IPS, 165Hz\n\u041f\u0440\u043e\u0446\u0435\u0441\u043e\u0440:Intel Core i5-13450HX Processor 2.4 GHz (20M Cache, up to 4.6 GHz, 10 cores)\n\u0413\u0440\u0430\u0444\u0438\u043a\u0430:NVIDIA GeForce RTX 4060 Laptop GPU 8GB GDDR6\nNVIDIA G-Sync\nRAM \u041c\u0435\u043c\u043e\u0440\u0438\u0458\u0430:16GB DDR5\n\u0414\u0438\u0441\u043a (Storage):1TB PCIe 4.0 NVMe M.2 SSD\n\u0411\u0435\u0437 \u043e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0435\u043d \u0441\u0438\u0441\u0442\u0435\u043c\nLAN 10/100/1000 Mbps\nWi-Fi 6E(802.11ax) (Triple band) 2*2 + Bluetooth 5.3\n\u041f\u043e\u0440\u0442\u0438:\n1x RJ45 LAN port\n1x Thunderbolt 4 support DisplayPort\n1x USB 3.2 Gen 2 Type-C support\n1x HDMI 2.1 FRL\n1x 3.5mm Combo Audio Jack\n720P HD camera\n\u0412\u0433\u0430\u0434\u0435\u043d \u043c\u0438\u043a\u0440\u043e\u0444\u043e\u043d\nBacklit Chiclet Keyboard 4-Zone RGB\n\u0417\u0432\u0443\u0447\u043d\u0438\u043a:\u0441\u0438\u0441\u0442\u0435\u043c \u0441\u043e 2 \u0437\u0432\u0443\u0447\u043d\u0438\u0446\u0438 \u0441\u043e Smart Amplifier Technology\n\u0410\u0443\u0434\u0438\u043e:\nTech AI noise-canceling - Dolby Atmos,Hi-Res certification\nAI noise-canceling technology\nDolby Atmos\nSmart Amp Technology\nSecurity BIOS Administrator Password and User Password Protection\n\u0411\u0430\u0442\u0435\u0440\u0438\u0458\u0430:90WHrs, 4S1P, 4-cell Li-ion"], "category": "gaming_laptopi"}
# {"url": "https://www.neptun.mk/categories/gaming_laptopi/ASUS-ROG-Strix-G16-G614JVR-N3086-16--i9-14900HX-16GB-DDR5-1TB-RTX-4060-8GB", "title": "\u041b\u0410\u041f\u0422\u041e\u041f ASUS ROG STRIX G16 G614JVR-N3086 16\" I9-14900HX/16GB DDR5/1TB/RTX 4060 8GB", "warranty": "24", "regular_price": "99.999", "happy_price": "92.999", "description": ["\u041b\u0430\u043f\u0442\u043e\u043f\n\u0414\u0438\u0441\u043f\u043b\u0435\u0458:16\" (40.6cm)\n\u0420\u0435\u0437\u043e\u043b\u0443\u0446\u0438\u0458\u0430:(1920 x 1200) WUXGA, IPS, 165Hz\n\u041f\u0440\u043e\u0446\u0435\u0441\u043e\u0440:Intel Core i9-14900HX (36M Cache, up to 5.8 GHz, 24 cores)\n\u0413\u0440\u0430\u0444\u0438\u043a\u0430:NVIDIA GeForce RTX 4060 8GB GDDR6\nNVIDIA G-Sync\nRAM \u041c\u0435\u043c\u043e\u0440\u0438\u0458\u0430:16GB DDR5\n\u0414\u0438\u0441\u043a (Storage):1TB PCIe 4.0 NVMe M.2 SSD\n\u0411\u0435\u0437 \u043e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0435\u043d \u0441\u0438\u0441\u0442\u0435\u043c\nLAN 10/100/1000 Mbps\nWi-Fi 6E(802.11ax) (Triple band) 2*2 + Bluetooth 5.3\n\u041f\u043e\u0440\u0442\u0438:\n1x RJ45 LAN port\n1x Thunderbolt    4 support DisplayPort\n1x USB 3.2 Gen 2 Type-C support DisplayPort    / power delivery / G-SYNC\n2x USB 3.2 Gen 2 Type-A\n1x HDMI 2.1 FRL\n1x 3.5mm Combo Audio Jack\n720P HD camera\n\u0412\u0433\u0430\u0434\u0435\u043d \u043c\u0438\u043a\u0440\u043e\u0444\u043e\u043d\nBacklit Chiclet Keyboard 4-Zone RGB\n\u0417\u0432\u0443\u0447\u043d\u0438\u043a:\u0441\u0438\u0441\u0442\u0435\u043c \u0441\u043e 2 \u0437\u0432\u0443\u0447\u043d\u0438\u0446\u0438 \u0441\u043e Smart Amplifier Technology\n\u0410\u0443\u0434\u0438\u043e:\nTech AI noise-canceling - Dolby Atmos,Hi-Res certification\nAI noise-canceling technology\nDolby Atmos\nHi-Res certification\nSmart Amp Technology\nSecurity BIOS Administrator Password and User Password Protection\n\u0411\u0430\u0442\u0435\u0440\u0438\u0458\u0430:90WHrs, 4S1P, 4-cell Li-ion"], "category": "gaming_laptopi"}
# {"url": "https://www.neptun.mk/categories/gaming_laptopi/ASUS-ROG-Strix-G17-G713RM-KH011-R7-6800H-16GB-1TB-RTX-3060-6GB", "title": "\u041b\u0410\u041f\u0422\u041e\u041f ASUS ROG STRIX G17 G713RM-KH011 R7-6800H/16GB/1TB/RTX 3060 6GB", "warranty": "24", "regular_price": "105.999", "happy_price": "81.999", "description": ["\u041b\u0430\u043f\u0442\u043e\u043f\n\u0414\u0438\u0441\u043f\u043b\u0435\u0458:17.3\" (43.9cm)\n\u0420\u0435\u0437\u043e\u043b\u0443\u0446\u0438\u0458\u0430:(1920 x 1080) FHD IPS 360Hz\n\u041f\u0440\u043e\u0446\u0435\u0441\u043e\u0440:AMD Rembrandt R7-H (TBD) R7-6800H\n\u0413\u0440\u0430\u0444\u0438\u043a\u0430:NVIDIA GeForce RTX 3060 6GB\n\u0412\u043d\u0430\u0442\u0440\u0435\u0448\u043d\u0430 \u043c\u0435\u043c\u043e\u0440\u0438\u0458\u0430:16GB DDR5\n\u041c\u0435\u043c\u043e\u0440\u0438\u0458\u0430:1TB SSD\n\u0411\u0435\u0437 \u043e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0435\u043d \u0441\u0438\u0441\u0442\u0435\u043c\nLAN 10/100/1000/2500 Mbps\nWi-Fi/Bluetooth Wi-Fi 6E(802.11ax)+Bluetooth 5.2 (Dual band) 2*2\n\u041f\u043e\u0440\u0442\u0438:\n1 x RJ45 LAN port\n1 x USB 3.2 Gen 2 Type-C\n1 x USB 3.2 Gen 2 Type-C support DisplayPort / power delivery\n2 x USB 3.2 Gen 1 Type-A//1x 3.5mm Combo Audio Jack\n1 x HDMI 2.0b\n\u041e\u0441\u0432\u0435\u0442\u043b\u0435\u043d\u0430 \u0442\u0430\u0441\u0442\u0430\u0442\u0443\u0440\u0430:4-Zone RGB\n\u0417\u0432\u0443\u0447\u043d\u0438\u0446\u0438:2-speaker system with Smart Amplifier Technology\nAudio Tech AI noise-canceling technology\nDolby Atmos\nHi-Res certification\nSmart Amp Technology\n\u0411\u0430\u0442\u0435\u0440\u0438\u0458\u0430:90WHrs, 4S1P, 4-cell Li-ion"], "category": "gaming_laptopi"}
# {"url": "https://www.neptun.mk/categories/gaming_laptopi/ASUS-ROG-Zephyrus-G14-GA403UI-QS048W-14--OLED-R9-8945HS-16GB-DDR5X-1TB-RTX-4070-8GB-WIN11", "title": "", "warranty": "24", "regular_price": "139.999", "happy_price": "129.999", "description": ["\u041b\u0430\u043f\u0442\u043e\u043f\n\u0414\u0438\u0441\u043f\u043b\u0435\u0458: 14\" (39.6cm)\n\u0420\u0435\u0437\u043e\u043b\u0443\u0446\u0438\u0458\u0430:(2880 x 1800) 3\u041a, OLED, 120Hz, 0.2ms, 500 nits, 16:10\n\u041f\u0440\u043e\u0446\u0435\u0441\u043e\u0440:AMD Ryzen\u2122 9 8945HS, 4GHz (24MB Cache, up to 5.2 GHz, 8 cores, 16 Threads)\n\u0413\u0440\u0430\u0444\u0438\u043a\u0430:NVIDIA GeForce RTX 4070 8GB GDDR6\nRAM \u043c\u0435\u043c\u043e\u0440\u0438\u0458\u0430:16GB DDR5X\n\u0414\u0438\u0441\u043a (Storage):1TB M.2 2280 PCIe Gen4 SSD\n\u041e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0435\u043d \u0441\u0438\u0441\u0442\u0435\u043c:Windows 11 Home\nWi-Fi 6E(802.11ax) (Triple band) 2*2 + Bluetooth 5.3\n\u041f\u043e\u0440\u0442\u0438:\n1x Type C USB 4 support DisplayPort    / power delivery\n1x USB 3.2 Gen 2 Type-C support DisplayPor\n2x USB 3.2 Gen 2 Type-A\n1x card reader (microSD) (UHS-II)\n1x HDMI 2.1 FRL\n1x 3.5mm Combo Audio Jack\n\u0412\u0433\u0430\u0434\u0435\u043d\u0438 3 \u043c\u0438\u043a\u0440\u043e\u0444\u043e\u043d\u0438\nBacklit Chiclet Keyboard 1-Zone RGB\n4x \u0437\u0432\u0443\u0447\u043d\u0438\u0446\u0438 (4-speaker (dual force woofer) system with Smart Amplifier Technology)\n\u0410\u0443\u0434\u0438\u043e:Tech AI noise-canceling - Dolby Atmos\nHi-Res certification\nSmart Amp Technology\nSecurity BIOS Administrator Password and User Password Protection\n\u0411\u0430\u0442\u0435\u0440\u0438\u0458\u0430:73WHrs, 4S1P, 4-cell Li-ion"], "category": "gaming_laptopi"}
# {"url": "https://www.neptun.mk/categories/gaming_laptopi/ASUS-ROG-Zephyrus-G14-GA403UU-QS055W-14--OLED-R9-8945HS-16GB-DDR5X-1TB-RTX-4050-6GB-WIN11", "title": "\u041b\u0410\u041f\u0422\u041e\u041f ASUS ROG ZEPHYRUS G14 GA403UU-QS055W 14\" OLED R9-8945HS/16GB DDR5X/1TB/RTX 4050 6GB/WIN11", "warranty": "24", "regular_price": "112.999", "happy_price": "104.999", "description": ["\u041b\u0430\u043f\u0442\u043e\u043f\n\u0414\u0438\u0441\u043f\u043b\u0435\u0458: 14\" (39.6cm)\n\u0420\u0435\u0437\u043e\u043b\u0443\u0446\u0438\u0458\u0430:(2880 x 1800) 3\u041a, OLED, 120Hz, 0.2ms, 500 nits, 16:10\n\u041f\u0440\u043e\u0446\u0435\u0441\u043e\u0440:AMD Ryzen\u2122 9 8945HS, 4GHz (24MB Cache, up to 5.2 GHz, 8 cores, 16 Threads)\n\u0413\u0440\u0430\u0444\u0438\u043a\u0430:NVIDIA GeForce RTX 4050 6GB GDDR6\nRAM \u043c\u0435\u043c\u043e\u0440\u0438\u0458\u0430:16GB DDR5X\n\u0414\u0438\u0441\u043a (Storage):1TB M.2 2280 PCIe Gen4 SSD\n\u041e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0435\u043d \u0441\u0438\u0441\u0442\u0435\u043c:Windows 11 Home\nWi-Fi 6E(802.11ax) (Triple band) 2*2 + Bluetooth 5.3\n\u041f\u043e\u0440\u0442\u0438:\n1x Type C USB 4 support DisplayPort    / power delivery\n1x USB 3.2 Gen 2 Type-C support DisplayPor\n2x USB 3.2 Gen 2 Type-A\n1x card reader (microSD) (UHS-II)\n1x HDMI 2.1 FRL\n1x 3.5mm Combo Audio Jack\n\u0412\u0433\u0430\u0434\u0435\u043d\u0438 3 \u043c\u0438\u043a\u0440\u043e\u0444\u043e\u043d\u0438\nBacklit Chiclet Keyboard 1-Zone RGB\n4x \u0437\u0432\u0443\u0447\u043d\u0438\u0446\u0438 (4-speaker (dual force woofer) system with Smart Amplifier Technology)\n\u0410\u0443\u0434\u0438\u043e:Tech AI noise-canceling - Dolby Atmos\nHi-Res certification\nSmart Amp Technology\nSecurity BIOS Administrator Password and User Password Protection\n\u0411\u0430\u0442\u0435\u0440\u0438\u0458\u0430:73WHrs, 4S1P, 4-cell Li-ion"], "category": "gaming_laptopi"}
# {"url": "https://www.neptun.mk/categories/gaming_laptopi/ASUS-ROG-Zephyrus-G16-GU603ZV-N4008W-16--i7-12700H-16GB-1TB-RTX-4060-8GB-WIN11", "title": "\u041b\u0410\u041f\u0422\u041e\u041f ASUS ROG ZEPHYRUS G16 GU603ZV-N4008W 16\" I7-12700H/16GB/1TB/RTX 4060 8GB/WIN11", "warranty": "24", "regular_price": "119.999", "happy_price": "99.999", "description": ["\u041b\u0430\u043f\u0442\u043e\u043f\n\u0414\u0438\u0441\u043f\u043b\u0435\u0458:16.0\" (40.6cm)\n\u0420\u0435\u0437\u043e\u043b\u0443\u0446\u0438\u0458\u0430:(2560 x 1600) WQXGA IPS 240Hz\n\u041f\u0440\u043e\u0446\u0435\u0441\u043e\u0440:12th Gen Intel Core i7-12700H Processor 2.3 GHz (24M Cache, up to 4.7 GHz, 14 cores)\n\u0413\u0440\u0430\u0444\u0438\u043a\u0430:GeForce RTX 4060 8GB GDDR6\nRAM \u041c\u0435\u043c\u043e\u0440\u0438\u0458\u0430:16GB DDR4\n\u0414\u0438\u0441\u043a (Storage):1TB PCIe 4.0 NVMe M.2 SSD\n\u041e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0435\u043d \u0441\u0438\u0441\u0442\u0435\u043c:Windows 11 Home\nLAN 10/100/1000 Mbps\nWi-Fi 6E(802.11ax) (Triple band) 2*2 + Bluetooth 5.2\n\u041f\u043e\u0440\u0442\u0438:\n1x RJ45 LAN port\n1x Thunderbolt 4 support DisplayPort / power delivery\n1x USB 3.2 Gen 2 Type-C support DisplayPort / power delivery / G-SYNC\n2x USB 3.2 Gen 2 Type-A\n1x card reader (microSD) (UHS-II, 312MB/s)\n1x HDMI 2.1 FRL\n1x 3.5mm Combo Audio Jack\n720P HD IR Camera for Windows Hello\n\u0412\u0433\u0430\u0434\u0435\u043d \u043c\u0438\u043a\u0440\u043e\u0444\u043e\u043d\n\u041e\u0441\u0432\u0435\u0442\u043b\u0435\u043d\u0430 \u0442\u0430\u0441\u0442\u0430\u0442\u0443\u0440\u0430 RGB\n\u0417\u0432\u0443\u0447\u043d\u0438\u043a:2x 2W speaker\n\u0410\u0443\u0434\u0438\u043e:Tech AI noise-canceling - Dolby Atmos\nSecurity BIOS Administrator Password and User Password Protection\n\u0411\u0430\u0442\u0435\u0440\u0438\u0458\u0430:90WHrs, 4S1P, 4-cell Li-ion"], "category": "gaming_laptopi"}
# {"url": "https://www.neptun.mk/categories/gaming_laptopi/ASUS-ROG-Zephyrus-G16-GU605MI-QR153W-16--OLED-Ultra-7-155H-32GB-DDR5X-1TB-RTX-4070-8GB-WIN11", "title": "\u041b\u0410\u041f\u0422\u041e\u041f ASUS ROG ZEPHYRUS G16 GU605MI-QR153W 16\" OLED ULTRA 7 155H/32GB DDR5X/1TB/RTX 4070 8GB/WIN11", "warranty": "24", "regular_price": "159.999", "happy_price": "147.999", "description": ["\u041b\u0430\u043f\u0442\u043e\u043f\n\u0414\u0438\u0441\u043f\u043b\u0435\u0458:16.0\" (40.6cm)\n\u0420\u0435\u0437\u043e\u043b\u0443\u0446\u0438\u0458\u0430:(2560 x 1600) 2.5K, WQXGA OLED 240Hz, 0.2ms, 500 nits\n\u041f\u0440\u043e\u0446\u0435\u0441\u043e\u0440:Intel\u00ae Core\u2122 Ultra 7 155H, 16-Cores, 24M Cache, up to 4.80 GHz\n\u0413\u0440\u0430\u0444\u0438\u043a\u0430:Nvidia Geforce RTX 4070 8GB GDDR6\nRAM \u043c\u0435\u043c\u043e\u0440\u0438\u0458\u0430:32GB DDR5X\n\u0414\u0438\u0441\u043a (Storage):1TB PCIe 4.0 NVMe M.2 SSD\n\u041e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0435\u043d \u0441\u0438\u0441\u0442\u0435\u043c:Windows 11 Home\nAdaptive-Sync technology: G-Sync\nWi-Fi 6E(802.11ax) (Triple band) 2*2 + Bluetooth 5.3\n\u041f\u043e\u0440\u0442\u0438:\n1x Thunderbolt 4 support DisplayPort / power delivery\n1x USB 3.2 Gen 2 Type-C support DisplayPort    / power delivery\n2x USB 3.2 Gen 2 Type-A\n1x card reader (SD) (UHS-II, 312MB/s)\n1x HDMI 2.1 FRL\n1x 3.5mm Combo Audio Jack\n\u041a\u0430\u043c\u0435\u0440\u0430: 1080P FHD IR Camera for Windows Hello\n\u0412\u0433\u0430\u0434\u0435\u043d\u0438 \u043c\u0438\u043a\u0440\u043e\u0444\u043e\u043d\u0438\nBacklit Chiclet Keyboard 1-Zone RGB\nAura Sync\n\u0417\u0432\u0443\u0447\u043d\u0438\u043a:4-speaker (dual force woofer) system with Smart Amplifier Technology\n\u0410\u0443\u0434\u0438\u043e:Tech AI noise-canceling\nDolby Atmos\nHi-Res certification\nSmart Amp Technology\nSecurity BIOS Administrator Password and User Password Protection\n\u0411\u0430\u0442\u0435\u0440\u0438\u0458\u0430:90WHrs, 4S1P, 4-cell Li-ion"], "category": "gaming_laptopi"}
# ...
# {"url": "https://www.neptun.mk/categories/gaming_laptopi/HP-Victus-16-r0078nia-16-1--i5-13500H-16GB-DDR5-512GB-RTX-4050-6GB", "title": "\u041b\u0410\u041f\u0422\u041e\u041f HP VICTUS 16-R0078NIA 16.1\" I5-13500H/16GB DDR5/512GB/RTX 4050 6GB", "warranty": "12", "regular_price": "72.999", "happy_price": "63.999", "description": ["\u041b\u0430\u043f\u0442\u043e\u043f\n\u0414\u0438\u0441\u043f\u043b\u0435\u0458:16.1\" (40.9cm)\n\u0420\u0435\u0437\u043e\u043b\u0443\u0446\u0438\u0458\u0430:(1920 x 1080) FHD IPS 144 Hz, micro-edge, anti-glare, 250 nits, 45% NTSC\n\u041f\u0440\u043e\u0446\u0435\u0441\u043e\u0440:Intel\u00ae Core\u2122 i5-13500H (up to 4.7 GHz with Intel\u00ae Turbo Boost Technology, 18 MB L3 cache, 12 cores, 16 threads)\n\u0413\u0440\u0430\u0444\u0438\u043a\u0430:NVIDIA\u00ae GeForce RTX\u2122 4050 6 GB GDDR6\n\u0412\u043d\u0430\u0442\u0440\u0435\u0448\u043d\u0430 \u043c\u0435\u043c\u043e\u0440\u0438\u0458\u0430:16 GB DDR5-5200 MHz RAM (2 x 8 GB)\n\u041c\u0435\u043c\u043e\u0440\u0438\u0458\u0430:512 GB PCIe\u00ae Gen4 NVMe\u2122 TLC M.2 SSD\nWi-Fi 6 MT7921 (2x2) + Bluetooth\u00ae 5.3\n\u041a\u0430\u043c\u0435\u0440\u0430:HP True Vision 1080p FHD camera with temporal noise reduction and integrated dual array digital microphones\n\u0410\u0443\u0434\u0438\u043e:Audio by B&O; Dual speakers; HP Audio Boost\nNetwork:10/100/1000 GbE LAN\n\u0410\u0443\u0434\u0438\u043e: B&O; Dual speakers; HP Audio Boost\n\u041f\u043e\u0440\u0442\u0438:\n1 USB Type-A 5Gbps signaling rate (HP Sleep and Charge)\n1 USB Type-C\u00ae 5Gbps signaling rate (USB Power Delivery, DisplayPort\u2122 1.4, HP Sleep and Charge)\n2 USB Type-A 5Gbps signaling rate\n1 HDMI 2.1\n1 RJ-45\n1 AC smart pin\n1 headphone/microphone combo[\nPower:230 W Smart AC power adapter\n\u0411\u0430\u0442\u0435\u0440\u0438\u0458\u0430:4-cell, 70 Wh Li-ion polymer"], "category": "gaming_laptopi"}
# {"url": "https://www.neptun.mk/categories/gaming_laptopi/LENOVO-Gaming-3-15ACH6-R5-5600H-16GB-512GB-GTX-1650-4GB", "title": "\u041b\u0410\u041f\u0422\u041e\u041f LENOVO GAMING 3 15ACH6 R5-5600H/16GB/512GB/GTX 1650 4GB", "warranty": "24", "regular_price": "44.999", "happy_price": "40.999", "description": ["\u041b\u0430\u043f\u0442\u043e\u043f\n\u0414\u0438\u0441\u043f\u043b\u0435\u0458:15.6\" (39.6cm)\n\u0420\u0435\u0437\u043e\u043b\u0443\u0446\u0438\u0458\u0430:(1920x1080) FHD, IPS 250nits Anti-glare, 45% NTSC\nChipset: AMD SoC Platform\n\u041f\u0440\u043e\u0446\u0435\u0441\u043e\u0440:AMD Ryzen\u2122 5 5600H (6C / 12T, 3.3 / 4.2GHz, 3MB L2 / 16MB L3)\n\u0413\u0440\u0430\u0444\u0438\u0447\u043a\u0430:NVIDIA\u00ae GeForce GTX 1650 4GB GDDR6\nRAM \u043c\u0435\u043c\u043e\u0440\u0438\u0458\u0430:16GB DDR4-3200\n\u0414\u0438\u0441\u043a (Storage):512GB SSD M.2 2280 PCIe\u00ae 3.0x4 NVMe\u00ae\n\u0411\u0435\u0437 \u043e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0435\u043d \u0441\u0438\u0441\u0442\u0435\u043c\n\u0410\u0443\u0434\u0438\u043e: High Definition (HD) Audio, Realtek\u00ae ALC3287 codec\n\u0417\u0432\u0443\u0447\u043d\u0438\u043a:Stereo speakers, 2W x2, optimized with Nahimic Audio\n\u041a\u0430\u043c\u0435\u0440\u0430:HD 720p with Privacy Shutter\n\u0417\u0432\u0443\u0447\u043d\u0438\u0446\u0438: Stereo speakers, 2W x2, Nahimic Audio\n\u041c\u0438\u043a\u0440\u043e\u0444\u043e\u043d:2x, Array\n\u0422\u0430\u0441\u0442\u0430\u0442\u0443\u0440\u0430: White Backlit, English\nWireless:Wi-Fi\u00ae 6, 11ax 2x2 + BT5.1\n\u041f\u043e\u0440\u0442\u0438:\n2x USB 3.2 Gen 1\n1x USB-C\u00ae 3.2 Gen 1 (support data transfer only)\n1x HDMI\u00ae 2.0\n1x Ethernet (RJ-45)\n1x Headphone / microphone combo jack (3.5mm)\n1x Power connector\n\u0411\u0430\u0442\u0435\u0440\u0438\u0458\u0430: Integrated 45Wh\nMobileMark\u00ae 2018: 5 hr (45Wh)\nPower Adapter: 135W Slim Tip (3-pin)"], "category": "gaming_laptopi"}
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[17], line 18
#      15 print(text)
#      17 # Process the JSON data using the LangChain model
# ---> 18 structured_data = chain.invoke({"text": text})
#      20 # Determine the output file path
#      21 output_filename = f"processed_{filename}"
#
# File c:\Users\tomce\miniconda3\envs\myenv\Lib\site-packages\langchain\chains\base.py:166, in Chain.invoke(self, input, config, **kwargs)
#     164 except BaseException as e:
#     165     run_manager.on_chain_error(e)
# --> 166     raise e
#     167 run_manager.on_chain_end(outputs)
#     169 if include_run_info:
#
# File c:\Users\tomce\miniconda3\envs\myenv\Lib\site-packages\langchain\chains\base.py:156, in Chain.invoke(self, input, config, **kwargs)
#     153 try:
#     154     self._validate_inputs(inputs)
#     155     outputs = (
# --> 156         self._call(inputs, run_manager=run_manager)
#     157         if new_arg_supported
#     158         else self._call(inputs)
#     159     )
#     161     final_outputs: Dict[str, Any] = self.prep_outputs(
#     162         inputs, outputs, return_only_outputs
#     163     )
#     164 except BaseException as e:
#
# File c:\Users\tomce\miniconda3\envs\myenv\Lib\site-packages\langchain\chains\llm.py:126, in LLMChain._call(self, inputs, run_manager)
#     121 def _call(
#     122     self,
#     123     inputs: Dict[str, Any],
#     124     run_manager: Optional[CallbackManagerForChainRun] = None,
#     125 ) -> Dict[str, str]:
# --> 126     response = self.generate([inputs], run_manager=run_manager)
#     127     return self.create_outputs(response)[0]
#
# File c:\Users\tomce\miniconda3\envs\myenv\Lib\site-packages\langchain\chains\llm.py:138, in LLMChain.generate(self, input_list, run_manager)
#     136 callbacks = run_manager.get_child() if run_manager else None
#     137 if isinstance(self.llm, BaseLanguageModel):
# --> 138     return self.llm.generate_prompt(
#     139         prompts,
#     140         stop,
#     141         callbacks=callbacks,
#     142         **self.llm_kwargs,
#     143     )
#     144 else:
#     145     results = self.llm.bind(stop=stop, **self.llm_kwargs).batch(
#     146         cast(List, prompts), {"callbacks": callbacks}
#     147     )
#
# File c:\Users\tomce\miniconda3\envs\myenv\Lib\site-packages\langchain_core\language_models\chat_models.py:599, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     591 def generate_prompt(
#     592     self,
#     593     prompts: List[PromptValue],
#    (...)
#     596     **kwargs: Any,
#     597 ) -> LLMResult:
#     598     prompt_messages = [p.to_messages() for p in prompts]
# --> 599     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\tomce\miniconda3\envs\myenv\Lib\site-packages\langchain_core\language_models\chat_models.py:456, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     454         if run_managers:
#     455             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 456         raise e
#     457 flattened_outputs = [
#     458     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     459     for res in results
#     460 ]
#     461 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File c:\Users\tomce\miniconda3\envs\myenv\Lib\site-packages\langchain_core\language_models\chat_models.py:446, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     443 for i, m in enumerate(messages):
#     444     try:
#     445         results.append(
# --> 446             self._generate_with_cache(
#     447                 m,
#     448                 stop=stop,
#     449                 run_manager=run_managers[i] if run_managers else None,
#     450                 **kwargs,
#     451             )
#     452         )
#     453     except BaseException as e:
#     454         if run_managers:
#
# File c:\Users\tomce\miniconda3\envs\myenv\Lib\site-packages\langchain_core\language_models\chat_models.py:671, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     669 else:
#     670     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 671         result = self._generate(
#     672             messages, stop=stop, run_manager=run_manager, **kwargs
#     673         )
#     674     else:
#     675         result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\tomce\miniconda3\envs\myenv\Lib\site-packages\langchain_anthropic\chat_models.py:514, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#     512     data = self._client.beta.tools.messages.create(**params)
#     513 else:
# --> 514     data = self._client.messages.create(**params)
#     515 return self._format_output(data, **kwargs)
#
# File c:\Users\tomce\miniconda3\envs\myenv\Lib\site-packages\anthropic\_utils\_utils.py:277, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     275             msg = f"Missing required argument: {quote(missing[0])}"
#     276     raise TypeError(msg)
# --> 277 return func(*args, **kwargs)
#
# File c:\Users\tomce\miniconda3\envs\myenv\Lib\site-packages\anthropic\resources\messages.py:681, in Messages.create(self, max_tokens, messages, model, metadata, stop_sequences, stream, system, temperature, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     650 @required_args(["max_tokens", "messages", "model"], ["max_tokens", "messages", "model", "stream"])
#     651 def create(
#     652     self,
#    (...)
#     679     timeout: float | httpx.Timeout | None | NotGiven = 600,
#     680 ) -> Message | Stream[MessageStreamEvent]:
# --> 681     return self._post(
#     682         "/v1/messages",
#     683         body=maybe_transform(
#     684             {
#     685                 "max_tokens": max_tokens,
#     686                 "messages": messages,
#     687                 "model": model,
#     688                 "metadata": metadata,
#     689                 "stop_sequences": stop_sequences,
#     690                 "stream": stream,
#     691                 "system": system,
#     692                 "temperature": temperature,
#     693                 "top_k": top_k,
#     694                 "top_p": top_p,
#     695             },
#     696             message_create_params.MessageCreateParams,
#     697         ),
#     698         options=make_request_options(
#     699             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     700         ),
#     701         cast_to=Message,
#     702         stream=stream or False,
#     703         stream_cls=Stream[MessageStreamEvent],
#     704     )
#
# File c:\Users\tomce\miniconda3\envs\myenv\Lib\site-packages\anthropic\_base_client.py:1239, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1225 def post(
#    1226     self,
#    1227     path: str,
#    (...)
#    1234     stream_cls: type[_StreamT] | None = None,
#    1235 ) -> ResponseT | _StreamT:
#    1236     opts = FinalRequestOptions.construct(
#    1237         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1238     )
# -> 1239     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\tomce\miniconda3\envs\myenv\Lib\site-packages\anthropic\_base_client.py:921, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     912 def request(
#     913     self,
#     914     cast_to: Type[ResponseT],
#    (...)
#     919     stream_cls: type[_StreamT] | None = None,
#     920 ) -> ResponseT | _StreamT:
# --> 921     return self._request(
#     922         cast_to=cast_to,
#     923         options=options,
#     924         stream=stream,
#     925         stream_cls=stream_cls,
#     926         remaining_retries=remaining_retries,
#     927     )
#
# File c:\Users\tomce\miniconda3\envs\myenv\Lib\site-packages\anthropic\_base_client.py:1004, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1002 if retries > 0 and self._should_retry(err.response):
#    1003     err.response.close()
# -> 1004     return self._retry_request(
#    1005         options,
#    1006         cast_to,
#    1007         retries,
#    1008         err.response.headers,
#    1009         stream=stream,
#    1010         stream_cls=stream_cls,
#    1011     )
#    1013 # If the response is streamed then we need to explicitly read the response
#    1014 # to completion before attempting to access the response text.
#    1015 if not err.response.is_closed:
#
# File c:\Users\tomce\miniconda3\envs\myenv\Lib\site-packages\anthropic\_base_client.py:1052, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1048 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1049 # different thread if necessary.
#    1050 time.sleep(timeout)
# -> 1052 return self._request(
#    1053     options=options,
#    1054     cast_to=cast_to,
#    1055     remaining_retries=remaining,
#    1056     stream=stream,
#    1057     stream_cls=stream_cls,
#    1058 )
#
# File c:\Users\tomce\miniconda3\envs\myenv\Lib\site-packages\anthropic\_base_client.py:1004, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1002 if retries > 0 and self._should_retry(err.response):
#    1003     err.response.close()
# -> 1004     return self._retry_request(
#    1005         options,
#    1006         cast_to,
#    1007         retries,
#    1008         err.response.headers,
#    1009         stream=stream,
#    1010         stream_cls=stream_cls,
#    1011     )
#    1013 # If the response is streamed then we need to explicitly read the response
#    1014 # to completion before attempting to access the response text.
#    1015 if not err.response.is_closed:
#
# File c:\Users\tomce\miniconda3\envs\myenv\Lib\site-packages\anthropic\_base_client.py:1052, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1048 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1049 # different thread if necessary.
#    1050 time.sleep(timeout)
# -> 1052 return self._request(
#    1053     options=options,
#    1054     cast_to=cast_to,
#    1055     remaining_retries=remaining,
#    1056     stream=stream,
#    1057     stream_cls=stream_cls,
#    1058 )
#
# File c:\Users\tomce\miniconda3\envs\myenv\Lib\site-packages\anthropic\_base_client.py:1019, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1016         err.response.read()
#    1018     log.debug("Re-raising status error")
# -> 1019     raise self._make_status_error_from_response(err.response) from None
#    1021 return self._process_response(
#    1022     cast_to=cast_to,
#    1023     options=options,
#    (...)
#    1026     stream_cls=stream_cls,
#    1027 )
#
# RateLimitError: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your daily rate limit (https://docs.anthropic.com/en/api/rate-limits); see the response headers for current usage. Please reduce the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}

# %% [markdown]
# Input:
# {
#   "url": "https://www.neptun.mk/categories/gaming_laptopi/LENOVO-IdeaPad-Gaming-3-15ACH6-R5-5500H-16GB-512GB-RTX-2050-4GB",
#   "title": "",
#   "warranty": "24",
#   "regular_price": "39.999",
#   "happy_price": "36.999",
#   "description": [
#     "Лаптоп",
#     "Дисплеј:15.6\" (39.6cm)",
#     "Резолуција:(1920x1080) FHD, IPS 250nits Anti-glare, 45% NTSC, 60Hz",
#     "Chipset: AMD SoC Platform",
#     "Процесор:AMD Ryzen™ 5 5500H (4C / 8T, 3.3 / 4.2GHz, 2MB L2 / 8MB L3)",
#     "Графичка:NVIDIA® GeForce RTX™ 2050 4GB GDDR6",
#     "RAM меморија:16GB DDR4-3200",
#     "Диск (Storage):512GB SSD M.2 2242 PCIe® 4.0x4 NVMe®",
#     "Без оперативен систем",
#     "WLAN + Bluetooth: 11ac 2x2 + BT5.0",
#     "Камера:HD 720p with Privacy Shutter",
#     "Аудио: High Definition (HD) Audio, Realtek® ALC3287 codec",
#     "Звучници: Stereo speakers, 2W x2, Nahimic Audio",
#     "Микрофон:2x, Array",
#     "Тастатура: White Backlit, English",
#     "Wireless:Wi-Fi® 6, 11ax 2x2 + BT5.1",
#     "Порти:",
#     "2x USB 3.2 Gen 1",
#     "1x USB-C® 3.2 Gen 1 (support data transfer only)",
#     "1x HDMI® 2.0",
#     "1x Headphone / microphone combo jack (3.5mm)",
#     "1x Ethernet (RJ-45)",
#     "1x Power connector",
#     "Батерија: Integrated 45Wh",
#     "Power Adapter: 135W Slim Tip (3-pin)"
#   ],
#   "category": "gaming_laptopi"
# }
# Output:
# {
#   "url": "https://www.neptun.mk/categories/gaming_laptopi/LENOVO-IdeaPad-Gaming-3-15ACH6-R5-5500H-16GB-512GB-RTX-2050-4GB",
#   "title": "",
#   "regular_price": "39.999",
#   "happy_price": "36.999",
#   "warranty": "24",
#   "features": {
#     "Display": "15.6\" (39.6cm)",
#     "Resolution": "1920x1080 FHD, IPS 250nits Anti-glare",
#     "Chipset": "AMD SoC Platform",
#     "Processor": "AMD Ryzen™ 5 5500H (4C / 8T, 3.3 / 4.2GHz, 2MB L2 / 8MB L3)",
#     "Graphics": "NVIDIA® GeForce RTX™ 2050 4GB GDDR6",
#     "RAM": "16GB DDR4-3200",
#     "Storage": "512GB SSD M.2 2242 PCIe® 4.0x4 NVMe®",
#     "Operating System": "Без оперативен систем",
#     "Wireless": "Wi-Fi® 6, 11ax 2x2 + BT5.1",
#     "Camera": "HD 720p with Privacy Shutter",
#     "Audio": "High Definition (HD) Audio, Realtek® ALC3287 codec",
#     "Speakers": "Stereo speakers, 2W x2, Nahimic Audio",
#     "Microphone": "2x, Array",
#     "Keyboard": "White Backlit, English",
#     "Headset Port": "1 x Headset (headphone and microphone combo) port",
#     "RJ45 Ethernet Port": "1 x RJ45 Ethernet port",
#     "USB Ports": "3 x USB 3.2 Gen 1 ports",
#     "HDMI Port": "1 x HDMI 2.0 port",
#     "USB-C Port": "1 x USB-C 3.2 Gen 1 port (support data transfer only)",
#     "Battery": "Integrated 45Wh",
#     "Power Adapter": "135W Slim Tip (3-pin)",
#     "Display Port": false
#   }
# }
# Input:
# {
#   "url": "https://www.neptun.mk/categories/gaming_laptopi/ACER-AN515-57-53A7-i5-11400H-8GB-512B-RTX-3050-4GB",
#   "title": "ЛАПТОП ACER AN515-57-53A7 I5-11400H/8GB/512B/RTX 3050 4GB",
#   "warranty": "24",
#   "regular_price": "55.999",
#   "happy_price": "47.999",
#   "description": [
#     "Лаптоп",
#     "Дисплеј:15.6\" (39.6cm)",
#     "Резолуција:(1920 x 1080) FHD IPS 144Hz",
#     "Процесор:Intel® Core i5-11400H 2.70 GHz Hexa-core",
#     "Графика:NVIDIA® GeForce RTX 3050 4GB",
#     "RAM меморија:8GB DDR4",
#     "Диск (Storage):512GB SSD",
#     "LAN:IEEE 802.11 a/b/g/n/ac/ax",
#     "Gigabit Ethernet",
#     "Bluetooth 5.2",
#     "Микрофон",
#     "Оперативен систем:UEFI Shell",
#     "Порти:",
#     "HDMI, USB, LAN, Type C",
#     "Батерија:4-cell (Li-Ion) - 8h"
#   ],
#   "category": "gaming_laptopi"
# }
# Output:
# {
#   "url": "https://www.neptun.mk/categories/gaming_laptopi/ACER-AN515-57-53A7-i5-11400H-8GB-512B-RTX-3050-4GB",
#   "title": "ЛАПТОП ACER AN515-57-53A7 I5-11400H/8GB/512B/RTX 3050 4GB",
#   "regular_price": "55.999",
#   "happy_price": "47.999",
#   "warranty": "24",
#   "features": {
#     "Display": "15.6\" (39.6cm)",
#     "Resolution": "1920 x 1080 FHD IPS 144Hz",
#     "Processor": "Intel® Core i5-11400H 2.70 GHz Hexa-core",
#     "Graphics": "NVIDIA® GeForce RTX 3050 4GB",
#     "RAM": "8GB DDR4",
#     "Storage": "512GB SSD",
#     "LAN": "IEEE 802.11 a/b/g/n/ac/ax, Gigabit Ethernet",
#     "Bluetooth": "5.2",
#     "Microphone": true,
#     "Operating System": "UEFI Shell",
#     "HDMI Port": "1 x HDMI port",
#     "USB Port": "1 x USB port",
#     "LAN Port": "1 x LAN port",
#     "Type C Port": "1 x Type C port",
#     "Battery": "4-cell (Li-Ion) - 8h"
#   }
# }
#
# Input:
# {
# "url": "https://www.neptun.mk/categories/gaming_laptopi/DELL-G15-5530-i5-13450HX-16GB-DDR5-512GB-RTX-3050-6GB",
# "title": "ЛАПТОП DELL G15 5530 I5-13450HX/16GB DDR5/512GB/RTX 3050 6GB",
# "warranty": "36",
# "regular_price": "69.999",
# "happy_price": "62.999",
# "description": [
# "Лаптоп",
# "Дисплеј:15.6" (39.6cm)",
# "Резолуција: (1920 x 1080) FHD 120Hz 250 nits WVA Anti- Glare LED Backlit Narrow Border Display",
# "Процесор:13th Gen Intel® Core™ i5-13450HX (20 MB cache, 10 cores, 16 threads, up to 4.60 GHz Turbo)",
# "Графика:NVIDIA® GeForce RTX™ 3050, 6 GB GDDR6",
# "RAM Меморија: 16 GB: 2 x 8 GB, DDR5, 4800 MT/s",
# "Диск (Storage): 512 GB, M.2, PCIe NVMe, SSD",
# "Wi-Fi 6 AX201, 2x2, 802.11ax, Bluetooth® 5.2",
# "Камера:Integrated widescreen HD (720p) Webcam with Single Array Digital Microphone",
# "Порти:",
# "1 x Headset (headphone and microphone combo) port",
# "1 x RJ45 Ethernet port",
# "3 x USB 3.2 Gen 1 ports",
# "1 x HDMI 2.1 port",
# "1 x USB-C 3.2 Gen 2 port with DisplayPort™",
# "Батерија: 3 Cell, 56 Wh, integrated",
# "Полнач: 240W AC Adapter",
# "Позадинско осветлување на тастатурата (backlit keyboard)",
# "Carbon BlackDark Shadow Gray with Black thermal shelf"
# ],
# "category": "gaming_laptopi"
# }
# Output:
# {
#   "url": "https://www.neptun.mk/categories/gaming_laptopi/DELL-G15-5530-i5-13450HX-16GB-DDR5-512GB-RTX-3050-6GB",
#   "title": "ЛАПТОП DELL G15 5530 I5-13450HX/16GB DDR5/512GB/RTX 3050 6GB",
#   "warranty": "36",
#   "regular_price": "69.999",
#   "happy_price": "62.999",
#   "features": {
#     "Display": "15.6\" (39.6cm)",
#     "Resolution": "(1920 x 1080) FHD 120Hz 250 nits WVA Anti-Glare LED Backlit Narrow Border Display",
#     "Processor": "13th Gen Intel® Core™ i5-13450HX (20 MB cache, 10 cores, 16 threads, up to 4.60 GHz Turbo)",
#     "Graphics": "NVIDIA® GeForce RTX™ 3050, 6 GB GDDR6",
#     "RAM": "16 GB: 2 x 8 GB, DDR5, 4800 MT/s",
#     "Storage": "512 GB, M.2, PCIe NVMe, SSD",
#     "Wireless": "Wi-Fi 6 AX201, 2x2, 802.11ax, Bluetooth® 5.2",
#     "Camera": "Integrated widescreen HD (720p) Webcam with Single Array Digital Microphone",
#     "Headset Port": "1 x Headset (headphone and microphone combo) port",
#     "RJ45 Ethernet Port": "1 x RJ45 Ethernet port",
#     "USB Ports": "3 x USB 3.2 Gen 1 ports",
#     "HDMI Port": "1 x HDMI 2.1 port",
#     "USB-C Port": "1 x USB-C 3.2 Gen 2 port™",
#     "Display Port": true,
#     "Battery": "3 Cell, 56 Wh, integrated",
#     "Power Adapter": "240W AC Adapter",
#     "Backlit Keyboard": "Pozadinsko осветлување на тастатурата (backlit keyboard)",
#     "Color": "Carbon BlackDark Shadow Gray with Black thermal shelf"
#   }
# }
